# %% [markdown]
# ## Example 5.4 Cylindrical symmetry problem with internal volume constraint

# %% [markdown]
# This example shows the solution of an axi-symmetric problem with an internal constraint.
# The domain includes a cavity whose volume is kept constant during the simulation but its shape is arbitrary.

# %%
using LinearAlgebra
using Printf, AbaqusReader, Logging
using PyCall, PyPlot

# %%
using AD4SM

# %% [markdown]
# a few helper functions to sort the nodes of the internal boundary, calculate the volume of the cavity and quick plotting the solution in the notebook

# %%
mean(x) = sum(x)/length(x)
norm(x) = sqrt(sum(x.^2))
#
#
# sort_bnd sorts the nodes of the boundary to 
# form a path without self-intersections
function sort_bnd(nodes, nid_bnd)
  closest(node0, nodes) = findmin([norm(node0-node) for node in nodes])[2]

  id_srtd   = [nid_bnd[1],]
  lastnode  = nid_bnd[1]
  bnd_nodes = nid_bnd[2:end]

  while !isempty(bnd_nodes)
    idd = closest(nodes[lastnode], nodes[bnd_nodes])
    lastnode = bnd_nodes[idd]
    push!(id_srtd, bnd_nodes[idd])
    deleteat!(bnd_nodes, idd)
  end
  return id_srtd
end

# get_vol calculates the volume of the cavity
get_vol(p0) = π/2*sum(
  (p0[2:2:end-2]+p0[4:2:end]) .* 
  (p0[3:2:end]-p0[1:2:end-2]) .* 
  (p0[3:2:end]+p0[1:2:end-2]) )
#
# functions for plotting
#
function get_I1(elems, u0)
    F   = Elements.getinfo(elems,u0,info=:F)
    [ Materials.getInvariants(transpose(F)*F)[1] for F in F] 
end
function get_I3(elems, u0)
    F   = Elements.getinfo(elems,u0,info=:F)
    [ Materials.getInvariants(transpose(F)*F)[3] for F in F] 
end
patch = pyimport("matplotlib.patches")
coll  = pyimport("matplotlib.collections")  
function plot_model(elems, nodes; 
                    u = zeros(length(nodes[1]), length(nodes)),
                    Φ = [],
                    linewidth = 0.25,
                    facecolor = :c,
                    edgecolor = :b, 
                    alpha     = 1,
                    cmap      = :hsv,
                    clim      = [],
                    dTol      = 1e-6,
                    cfig      = figure(),
                    ax        = cfig.add_subplot(1,1,1))

  nodes     = [node + u[:,ii] for (ii,node) in enumerate(nodes)]
  patchcoll = coll.PatchCollection([patch.Polygon(nodes[elem.nodes]) 
                                    for elem ∈ elems], cmap=cmap)
    if !isempty(Φ)
    patchcoll.set_array(Φ)
    cfig.colorbar.(patchcoll, ax=ax)

    if isempty(clim)
      clim = patchcoll.get_clim()
      if abs(clim[2]-clim[1]) < dTol
        clim  = sum(clim)/2*[0.9, 1.1]
      end
    end
    patchcoll.set_clim(clim)
  else
    patchcoll.set_color(facecolor)
  end

  patchcoll.set_edgecolor(edgecolor)
  patchcoll.set_alpha(alpha)
  patchcoll.set_linewidth(linewidth)

  ax.set_aspect("equal")
  ax.add_collection(patchcoll)
  ax.autoscale()
  (cfig, ax, patchcoll)
end
;

# %%
sMeshFile = "AxSymDomainj.inp"
mat       = Materials.MooneyRivlin(1e1, 1e1, 1e3)
Δu        = 18
sPosFix   = "NHd"
N         = 200
LF        = range(1/10N, 1, length=N)
dTol      = 1e-6
ballus    = true
# sFileName = splitext(basename(sMeshFile))[1];
;

# %%
mymodel   = with_logger(Logging.NullLogger()) do
  AbaqusReader.abaqus_read_mesh(sMeshFile)
end
@printf("\n\t loaded %s \n", sMeshFile)

nodes     = [mymodel["nodes"][ii] for ii in 1:mymodel["nodes"].count]
el_nodes  = [item[2]              for item in mymodel["elements"]] 

# for node in nodes
#   node[1]-=10
# end

id_btm   = mymodel["node_sets"]["BTM"]
id_top   = mymodel["node_sets"]["TOP"]
id_bnd   = mymodel["node_sets"]["BND"]

elems     = [Elements.ASQuad(item, nodes[item], mat=mat) for item ∈ el_nodes]

@show (nNodes, nElems) = (length(nodes), length(elems)); flush(stdout)

# sort the internal boundary nodes
#
id_srtd   = sort_bnd(nodes, id_bnd);
push!(id_srtd, id_srtd[1])
pos0      = hcat(nodes[id_srtd]...)
idxu      = LinearIndices((2,nNodes))
@show V0  = get_vol(pos0)

pos_btm   = hcat(nodes[sort_bnd(nodes, id_btm)]...)
pos_top   = hcat(nodes[sort_bnd(nodes, id_top)]...)
;
# Out:
# 	 loaded AxSymDomainj.inp
# (nNodes, nElems) = (length(nodes), length(elems)) = (916, 796)
# V0 = get_vol(pos0) = 221925.20483454564

# %%
plot_model(elems, nodes)
PyPlot.plot(pos0[1,:], pos0[2,:], color=:b)        
PyPlot.plot(pos_btm[1,:], pos_btm[2,:], color=:r)        
PyPlot.plot(pos_top[1,:], pos_top[2,:], color=:r)        
PyPlot.title("Undeformed domain")
;
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# ### Solve the model with no cavity volume constraint

# %%
# displacement boundary conditions
u0     = 1e-5randn(2, nNodes)
idxu   = LinearIndices(u0)
bifree = trues(size(u0))

bifree[:,id_btm] .= false
bifree[2,id_top] .= false

u0[:,id_btm] .= 0
u0[2,id_top] .= 0

;

# %%
println("doing the 0-th step without volume constraint ... ");
@time Solvers.solvestep!(elems, u0, u0, bifree, dTol=dTol)
;
# Out:
# doing the 0-th step without volume constraint ...
#   9.483065 seconds (28.23 M allocations: 1.500 GiB, 8.58% gc time, 97.15% compilation time)

# %%
u            = copy(u0)
u[:,id_btm] .= 0
u[2,id_top] .= -Δu

println("doing the case without volume constraint ... ")
@time allus_e = Solvers.solve(elems, u, ifree=bifree, LF=range(1/10N, 1, length=N),
                     becho=true, bechoi=false, ballus=ballus,
                     dTolu=1e-6, dTole=1e-2, maxiter=15)
;
# Out:
# doing the case without volume constraint ...
# step   1/200, LF=0.001, done in  2 iter, after 0.18 sec.
# step   2/200, LF=0.006, done in  2 iter, after 0.16 sec.
# step   3/200, LF=0.011, done in  2 iter, after 0.18 sec.
# step   4/200, LF=0.016, done in  2 iter, after 0.18 sec.
# step   5/200, LF=0.021, done in  2 iter, after 0.18 sec.
# step   6/200, LF=0.026, done in  2 iter, after 0.18 sec.
# step   7/200, LF=0.031, done in  2 iter, after 0.19 sec.
# step   8/200, LF=0.036, done in  2 iter, after 0.19 sec.
# step   9/200, LF=0.041, done in  2 iter, after 0.19 sec.
# step  10/200, LF=0.046, done in  2 iter, after 0.19 sec.
# step  11/200, LF=0.051, done in  2 iter, after 0.19 sec.
# step  12/200, LF=0.056, done in  2 iter, after 0.19 sec.
# step  13/200, LF=0.061, done in  2 iter, after 0.19 sec.
# step  14/200, LF=0.066, done in  2 iter, after 0.19 sec.
# step  15/200, LF=0.071, done in  2 iter, after 0.22 sec.
# step  16/200, LF=0.076, done in  2 iter, after 0.19 sec.
# step  17/200, LF=0.081, done in  2 iter, after 0.19 sec.
# step  18/200, LF=0.086, done in  2 iter, after 0.18 sec.
# step  19/200, LF=0.091, done in  2 iter, after 0.20 sec.
# step  20/200, LF=0.096, done in  2 iter, after 0.19 sec.
# step  21/200, LF=0.101, done in  2 iter, after 0.20 sec.
# step  22/200, LF=0.106, done in  2 iter, after 0.20 sec.
# step  23/200, LF=0.111, done in  2 iter, after 0.20 sec.
# step  24/200, LF=0.116, done in  2 iter, after 0.20 sec.
# step  25/200, LF=0.121, done in  2 iter, after 0.21 sec.
# step  26/200, LF=0.126, done in  2 iter, after 0.20 sec.
# step  27/200, LF=0.131, done in  2 iter, after 0.20 sec.
# step  28/200, LF=0.136, done in  2 iter, after 0.20 sec.
# step  29/200, LF=0.141, done in  2 iter, after 0.20 sec.
# step  30/200, LF=0.146, done in  2 iter, after 0.20 sec.
# step  31/200, LF=0.151, done in  2 iter, after 0.20 sec.
# step  32/200, LF=0.156, done in  2 iter, after 0.20 sec.
# step  33/200, LF=0.161, done in  2 iter, after 0.20 sec.
# step  34/200, LF=0.166, done in  2 iter, after 0.20 sec.
# step  35/200, LF=0.171, done in  2 iter, after 0.20 sec.
# step  36/200, LF=0.176, done in  2 iter, after 0.21 sec.
# step  37/200, LF=0.181, done in  2 iter, after 0.20 sec.
# step  38/200, LF=0.186, done in  2 iter, after 0.20 sec.
# step  39/200, LF=0.191, done in  2 iter, after 0.20 sec.
# step  40/200, LF=0.196, done in  2 iter, after 0.20 sec.
# step  41/200, LF=0.201, done in  2 iter, after 0.20 sec.
# step  42/200, LF=0.206, done in  2 iter, after 0.21 sec.
# step  43/200, LF=0.211, done in  2 iter, after 0.20 sec.
# step  44/200, LF=0.216, done in  2 iter, after 0.21 sec.
# step  45/200, LF=0.221, done in  2 iter, after 0.21 sec.
# step  46/200, LF=0.227, done in  2 iter, after 0.21 sec.
# step  47/200, LF=0.232, done in  2 iter, after 0.21 sec.
# step  48/200, LF=0.237, done in  2 iter, after 0.21 sec.
# step  49/200, LF=0.242, done in  2 iter, after 0.21 sec.
# step  50/200, LF=0.247, done in  2 iter, after 0.21 sec.
# step  51/200, LF=0.252, done in  2 iter, after 0.21 sec.
# step  52/200, LF=0.257, done in  2 iter, after 0.21 sec.
# step  53/200, LF=0.262, done in  2 iter, after 0.20 sec.
# step  54/200, LF=0.267, done in  2 iter, after 0.21 sec.
# step  55/200, LF=0.272, done in  2 iter, after 0.21 sec.
# step  56/200, LF=0.277, done in  2 iter, after 0.21 sec.
# step  57/200, LF=0.282, done in  2 iter, after 0.21 sec.
# step  58/200, LF=0.287, done in  2 iter, after 0.21 sec.
# step  59/200, LF=0.292, done in  2 iter, after 0.21 sec.
# step  60/200, LF=0.297, done in  2 iter, after 0.21 sec.
# step  61/200, LF=0.302, done in  2 iter, after 0.21 sec.
# step  62/200, LF=0.307, done in  2 iter, after 0.21 sec.
# step  63/200, LF=0.312, done in  2 iter, after 0.21 sec.
# step  64/200, LF=0.317, done in  2 iter, after 0.21 sec.
# step  65/200, LF=0.322, done in  2 iter, after 0.21 sec.
# step  66/200, LF=0.327, done in  2 iter, after 0.21 sec.
# step  67/200, LF=0.332, done in  2 iter, after 0.21 sec.
# step  68/200, LF=0.337, done in  2 iter, after 0.21 sec.
# step  69/200, LF=0.342, done in  2 iter, after 0.21 sec.
# step  70/200, LF=0.347, done in  2 iter, after 0.21 sec.
# step  71/200, LF=0.352, done in  2 iter, after 0.21 sec.
# step  72/200, LF=0.357, done in  2 iter, after 0.21 sec.
# step  73/200, LF=0.362, done in  2 iter, after 0.21 sec.
# step  74/200, LF=0.367, done in  2 iter, after 0.21 sec.
# step  75/200, LF=0.372, done in  2 iter, after 0.21 sec.
# step  76/200, LF=0.377, done in  2 iter, after 0.22 sec.
# step  77/200, LF=0.382, done in  2 iter, after 0.22 sec.
# step  78/200, LF=0.387, done in  2 iter, after 0.21 sec.
# step  79/200, LF=0.392, done in  2 iter, after 0.22 sec.
# step  80/200, LF=0.397, done in  2 iter, after 0.21 sec.
# step  81/200, LF=0.402, done in  2 iter, after 0.21 sec.
# step  82/200, LF=0.407, done in  2 iter, after 0.21 sec.
# step  83/200, LF=0.412, done in  2 iter, after 0.21 sec.
# step  84/200, LF=0.417, done in  2 iter, after 0.22 sec.
# step  85/200, LF=0.422, done in  2 iter, after 0.21 sec.
# step  86/200, LF=0.427, done in  2 iter, after 0.22 sec.
# step  87/200, LF=0.432, done in  2 iter, after 0.22 sec.
# step  88/200, LF=0.437, done in  2 iter, after 0.21 sec.
# step  89/200, LF=0.442, done in  2 iter, after 0.22 sec.
# step  90/200, LF=0.448, done in  2 iter, after 0.21 sec.
# step  91/200, LF=0.453, done in  2 iter, after 0.21 sec.
# step  92/200, LF=0.458, done in  2 iter, after 0.22 sec.
# step  93/200, LF=0.463, done in  2 iter, after 0.21 sec.
# step  94/200, LF=0.468, done in  2 iter, after 0.22 sec.
# step  95/200, LF=0.473, done in  2 iter, after 0.22 sec.
# step  96/200, LF=0.478, done in  2 iter, after 0.22 sec.
# step  97/200, LF=0.483, done in  2 iter, after 0.22 sec.
# step  98/200, LF=0.488, done in  2 iter, after 0.21 sec.
# step  99/200, LF=0.493, done in  2 iter, after 0.22 sec.
# step 100/200, LF=0.498, done in  2 iter, after 0.21 sec.
# step 101/200, LF=0.503, done in  2 iter, after 0.22 sec.
# step 102/200, LF=0.508, done in  2 iter, after 0.21 sec.
# step 103/200, LF=0.513, done in  2 iter, after 0.22 sec.
# step 104/200, LF=0.518, done in  2 iter, after 0.23 sec.
# step 105/200, LF=0.523, done in  2 iter, after 0.29 sec.
# step 106/200, LF=0.528, done in  2 iter, after 0.27 sec.
# step 107/200, LF=0.533, done in  2 iter, after 0.28 sec.
# step 108/200, LF=0.538, done in  2 iter, after 0.21 sec.
# step 109/200, LF=0.543, done in  2 iter, after 0.22 sec.
# step 110/200, LF=0.548, done in  2 iter, after 0.21 sec.
# step 111/200, LF=0.553, done in  2 iter, after 0.22 sec.
# step 112/200, LF=0.558, done in  2 iter, after 0.27 sec.
# step 113/200, LF=0.563, done in  2 iter, after 0.35 sec.
# step 114/200, LF=0.568, done in  2 iter, after 0.39 sec.
# step 115/200, LF=0.573, done in  2 iter, after 0.39 sec.
# step 116/200, LF=0.578, done in  2 iter, after 0.23 sec.
# step 117/200, LF=0.583, done in  2 iter, after 0.21 sec.
# step 118/200, LF=0.588, done in  2 iter, after 0.20 sec.
# step 119/200, LF=0.593, done in  2 iter, after 0.22 sec.
# step 120/200, LF=0.598, done in  2 iter, after 0.21 sec.
# step 121/200, LF=0.603, done in  2 iter, after 0.22 sec.
# step 122/200, LF=0.608, done in  2 iter, after 0.21 sec.
# step 123/200, LF=0.613, done in  2 iter, after 0.22 sec.
# step 124/200, LF=0.618, done in  2 iter, after 0.21 sec.
# step 125/200, LF=0.623, done in  2 iter, after 0.22 sec.
# step 126/200, LF=0.628, done in  2 iter, after 0.21 sec.
# step 127/200, LF=0.633, done in  2 iter, after 0.22 sec.
# step 128/200, LF=0.638, done in  2 iter, after 0.21 sec.
# step 129/200, LF=0.643, done in  2 iter, after 0.22 sec.
# step 130/200, LF=0.648, done in  2 iter, after 0.22 sec.
# step 131/200, LF=0.653, done in  2 iter, after 0.21 sec.
# step 132/200, LF=0.658, done in  2 iter, after 0.22 sec.
# step 133/200, LF=0.663, done in  2 iter, after 0.21 sec.
# step 134/200, LF=0.669, done in  2 iter, after 0.22 sec.
# step 135/200, LF=0.674, done in  2 iter, after 0.22 sec.
# step 136/200, LF=0.679, done in  2 iter, after 0.21 sec.
# step 137/200, LF=0.684, done in  2 iter, after 0.22 sec.
# step 138/200, LF=0.689, done in  2 iter, after 0.21 sec.
# step 139/200, LF=0.694, done in  2 iter, after 0.22 sec.
# step 140/200, LF=0.699, done in  2 iter, after 0.25 sec.
# step 141/200, LF=0.704, done in  2 iter, after 0.20 sec.
# step 142/200, LF=0.709, done in  2 iter, after 0.22 sec.
# step 143/200, LF=0.714, done in  2 iter, after 0.20 sec.
# step 144/200, LF=0.719, done in  2 iter, after 0.22 sec.
# step 145/200, LF=0.724, done in  2 iter, after 0.22 sec.
# step 146/200, LF=0.729, done in  2 iter, after 0.22 sec.
# step 147/200, LF=0.734, done in  2 iter, after 0.22 sec.
# step 148/200, LF=0.739, done in  2 iter, after 0.22 sec.
# step 149/200, LF=0.744, done in  2 iter, after 0.22 sec.
# step 150/200, LF=0.749, done in  2 iter, after 0.22 sec.
# step 151/200, LF=0.754, done in  2 iter, after 0.22 sec.
# step 152/200, LF=0.759, done in  2 iter, after 0.22 sec.
# step 153/200, LF=0.764, done in  2 iter, after 0.22 sec.
# step 154/200, LF=0.769, done in  2 iter, after 0.22 sec.
# step 155/200, LF=0.774, done in  2 iter, after 0.22 sec.
# step 156/200, LF=0.779, done in  2 iter, after 0.22 sec.
# step 157/200, LF=0.784, done in  2 iter, after 0.23 sec.
# step 158/200, LF=0.789, done in  2 iter, after 0.23 sec.
# step 159/200, LF=0.794, done in  2 iter, after 0.18 sec.
# step 160/200, LF=0.799, done in  2 iter, after 0.21 sec.
# step 161/200, LF=0.804, done in  2 iter, after 0.23 sec.
# step 162/200, LF=0.809, done in  2 iter, after 0.23 sec.
# step 163/200, LF=0.814, done in  2 iter, after 0.23 sec.
# step 164/200, LF=0.819, done in  2 iter, after 0.23 sec.
# step 165/200, LF=0.824, done in  2 iter, after 0.23 sec.
# step 166/200, LF=0.829, done in  2 iter, after 0.23 sec.
# step 167/200, LF=0.834, done in  2 iter, after 0.23 sec.
# step 168/200, LF=0.839, done in  2 iter, after 0.24 sec.
# step 169/200, LF=0.844, done in  2 iter, after 0.24 sec.
# step 170/200, LF=0.849, done in  2 iter, after 0.24 sec.
# step 171/200, LF=0.854, done in  2 iter, after 0.24 sec.
# step 172/200, LF=0.859, done in  2 iter, after 0.24 sec.
# step 173/200, LF=0.864, done in  2 iter, after 0.24 sec.
# step 174/200, LF=0.869, done in  2 iter, after 0.24 sec.
# step 175/200, LF=0.874, done in  2 iter, after 0.23 sec.
# step 176/200, LF=0.879, done in  2 iter, after 0.23 sec.
# step 177/200, LF=0.884, done in  2 iter, after 0.23 sec.
# step 178/200, LF=0.890, done in  2 iter, after 0.24 sec.
# step 179/200, LF=0.895, done in  2 iter, after 0.23 sec.
# step 180/200, LF=0.900, done in  2 iter, after 0.23 sec.
# step 181/200, LF=0.905, done in  2 iter, after 0.23 sec.
# step 182/200, LF=0.910, done in  2 iter, after 0.24 sec.
# step 183/200, LF=0.915, done in  2 iter, after 0.24 sec.
# step 184/200, LF=0.920, done in  2 iter, after 0.24 sec.
# step 185/200, LF=0.925, done in  2 iter, after 0.25 sec.
# step 186/200, LF=0.930, done in  2 iter, after 0.25 sec.
# step 187/200, LF=0.935, done in  2 iter, after 0.25 sec.
# step 188/200, LF=0.940, done in  2 iter, after 0.24 sec.
# step 189/200, LF=0.945, done in  2 iter, after 0.24 sec.
# step 190/200, LF=0.950, done in  2 iter, after 0.25 sec.
# step 191/200, LF=0.955, done in  2 iter, after 0.27 sec.
# step 192/200, LF=0.960, done in  2 iter, after 0.24 sec.
# step 193/200, LF=0.965, done in  2 iter, after 0.24 sec.
# step 194/200, LF=0.970, done in  2 iter, after 0.24 sec.
# step 195/200, LF=0.975, done in  2 iter, after 0.24 sec.
# step 196/200, LF=0.980, done in  2 iter, after 0.24 sec.
# step 197/200, LF=0.985, done in  2 iter, after 0.24 sec.
# step 198/200, LF=0.990, done in  2 iter, after 0.24 sec.
# step 199/200, LF=0.995, done in  2 iter, after 0.24 sec.
# step 200/200, LF=1.000, done in  2 iter, after 0.24 sec.
# completed in 44 seconds
#  45.368649 seconds (58.23 M allocations: 46.475 GiB, 6.28% gc time, 3.49% compilation time)

# %%
cfig, ax = PyPlot.subplots()

plot_model(elems, nodes, cfig=cfig, ax=ax, 
  u=allus_e[end][1], Φ=get_I3(elems, allus_e[end][1]).-1)
;
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)

# %% [markdown]
# ### Solve the model including a constraint on the volume of the cavity

# %%
nid_bnd = length(id_srtd)
nDoFsu  = 2*nNodes
q       = 10
nGropus = ceil(Int, nid_bnd/q)

id_eqs_DoFs = [(ii-1)*q+1:ii*q+1 for ii in 1:nGropus-1]
append!(id_eqs_DoFs, [id_eqs_DoFs[end][end]:nid_bnd])

eqns = vcat(
  [begin
      id_bnd_ii = id_srtd[idx]
      idx_ii = idxu[:, id_bnd_ii][:]
      Solvers.ConstEq(x->get_vol(pos0[:,idx][:]+x[1:end-1])-x[end], 
                        vcat(idx_ii, nDoFsu+ii), adiff.D2)
      end for (ii,idx) in enumerate(id_eqs_DoFs)] ...,
  Solvers.ConstEq(x->sum(x)-V0, nDoFsu+1:nDoFsu+nGropus, adiff.D2))
@show nEqns = length(eqns)
;
# Out:
# nEqns = length(eqns) = 12

# %%
# displacement boundary conditions
idxu   = LinearIndices((2,nNodes))
u0     = 1e-4randn(2, nNodes+ceil(Int, nGropus/2))
bifree = trues(size(u0))
λ      = zeros(nEqns)

# make sure that the volume constraint is initially satisfied
for (ii, Eq) in enumerate(eqns[1:end-1])
  u0[nDoFsu+ii] = Eq.func(zeros(size(Eq.iDoFs)))
end

bifree[:,id_btm] .= false
bifree[2,id_top] .= false

u0[:,id_btm]     .= 0
u0[2,id_top]     .= 0
;

# %%
println("doing the 0-th step with volume constraint ... ");
@time Solvers.solvestep!(elems, u0, u0, bifree, λ=λ, dTolu=1e-5, dTole=1e-3, eqns=eqns)
;
# Out:
# doing the 0-th step with volume constraint ...
#  12.995066 seconds (27.63 M allocations: 1.439 GiB, 4.62% gc time, 97.60% compilation time)

# %%
u           = copy(u0)
u[:,id_btm] .= 0
u[2,id_top] .= -Δu


println("doing the case with volume constraint ... ")
@time allus_d = Solvers.solve(elems, u, ifree=bifree, λ=λ, eqns=eqns, LF=range(0, 1, length=200),
                     becho=true, bechoi=false, ballus=ballus, 
                     dTolu=1e-5, dTole=5e-2, maxiter=11)
;
# Out:
# doing the case with volume constraint ...
# step   1/200, LF=0.000, done in  2 iter, after 0.17 sec.
# step   2/200, LF=0.005, done in  2 iter, after 0.19 sec.
# step   3/200, LF=0.010, done in  2 iter, after 0.19 sec.
# step   4/200, LF=0.015, done in  2 iter, after 0.20 sec.
# step   5/200, LF=0.020, done in  2 iter, after 0.20 sec.
# step   6/200, LF=0.025, done in  2 iter, after 0.20 sec.
# step   7/200, LF=0.030, done in  2 iter, after 0.20 sec.
# step   8/200, LF=0.035, done in  2 iter, after 0.20 sec.
# step   9/200, LF=0.040, done in  2 iter, after 0.27 sec.
# step  10/200, LF=0.045, done in  2 iter, after 0.20 sec.
# step  11/200, LF=0.050, done in  2 iter, after 0.20 sec.
# step  12/200, LF=0.055, done in  2 iter, after 0.20 sec.
# step  13/200, LF=0.060, done in  2 iter, after 0.20 sec.
# step  14/200, LF=0.065, done in  2 iter, after 0.32 sec.
# step  15/200, LF=0.070, done in  2 iter, after 0.21 sec.
# step  16/200, LF=0.075, done in  2 iter, after 0.23 sec.
# step  17/200, LF=0.080, done in  2 iter, after 0.30 sec.
# step  18/200, LF=0.085, done in  2 iter, after 0.30 sec.
# step  19/200, LF=0.090, done in  2 iter, after 0.29 sec.
# step  20/200, LF=0.095, done in  2 iter, after 0.19 sec.
# step  21/200, LF=0.101, done in  2 iter, after 0.20 sec.
# step  22/200, LF=0.106, done in  2 iter, after 0.21 sec.
# step  23/200, LF=0.111, done in  2 iter, after 0.20 sec.
# step  24/200, LF=0.116, done in  2 iter, after 0.20 sec.
# step  25/200, LF=0.121, done in  2 iter, after 0.20 sec.
# step  26/200, LF=0.126, done in  2 iter, after 0.23 sec.
# step  27/200, LF=0.131, done in  2 iter, after 0.21 sec.
# step  28/200, LF=0.136, done in  2 iter, after 0.22 sec.
# step  29/200, LF=0.141, done in  2 iter, after 0.20 sec.
# step  30/200, LF=0.146, done in  2 iter, after 0.21 sec.
# step  31/200, LF=0.151, done in  2 iter, after 0.21 sec.
# step  32/200, LF=0.156, done in  2 iter, after 0.21 sec.
# step  33/200, LF=0.161, done in  2 iter, after 0.21 sec.
# step  34/200, LF=0.166, done in  2 iter, after 0.21 sec.
# step  35/200, LF=0.171, done in  2 iter, after 0.33 sec.
# step  36/200, LF=0.176, done in  2 iter, after 0.18 sec.
# step  37/200, LF=0.181, done in  2 iter, after 0.21 sec.
# step  38/200, LF=0.186, done in  2 iter, after 0.21 sec.
# step  39/200, LF=0.191, done in  2 iter, after 0.22 sec.
# step  40/200, LF=0.196, done in  2 iter, after 0.21 sec.
# step  41/200, LF=0.201, done in  2 iter, after 0.21 sec.
# step  42/200, LF=0.206, done in  2 iter, after 0.21 sec.
# step  43/200, LF=0.211, done in  2 iter, after 0.21 sec.
# step  44/200, LF=0.216, done in  2 iter, after 0.23 sec.
# step  45/200, LF=0.221, done in  2 iter, after 0.21 sec.
# step  46/200, LF=0.226, done in  2 iter, after 0.21 sec.
# step  47/200, LF=0.231, done in  2 iter, after 0.21 sec.
# step  48/200, LF=0.236, done in  2 iter, after 0.21 sec.
# step  49/200, LF=0.241, done in  2 iter, after 0.22 sec.
# step  50/200, LF=0.246, done in  2 iter, after 0.22 sec.
# step  51/200, LF=0.251, done in  2 iter, after 0.22 sec.
# step  52/200, LF=0.256, done in  2 iter, after 0.22 sec.
# step  53/200, LF=0.261, done in  2 iter, after 0.22 sec.
# step  54/200, LF=0.266, done in  2 iter, after 0.22 sec.
# step  55/200, LF=0.271, done in  2 iter, after 0.22 sec.
# step  56/200, LF=0.276, done in  2 iter, after 0.22 sec.
# step  57/200, LF=0.281, done in  2 iter, after 0.22 sec.
# step  58/200, LF=0.286, done in  2 iter, after 0.32 sec.
# step  59/200, LF=0.291, done in  2 iter, after 0.22 sec.
# step  60/200, LF=0.296, done in  2 iter, after 0.22 sec.
# step  61/200, LF=0.302, done in  2 iter, after 0.23 sec.
# step  62/200, LF=0.307, done in  2 iter, after 0.22 sec.
# step  63/200, LF=0.312, done in  2 iter, after 0.22 sec.
# step  64/200, LF=0.317, done in  2 iter, after 0.22 sec.
# step  65/200, LF=0.322, done in  2 iter, after 0.22 sec.
# step  66/200, LF=0.327, done in  2 iter, after 0.22 sec.
# step  67/200, LF=0.332, done in  2 iter, after 0.22 sec.
# step  68/200, LF=0.337, done in  2 iter, after 0.22 sec.
# step  69/200, LF=0.342, done in  2 iter, after 0.22 sec.
# step  70/200, LF=0.347, done in  2 iter, after 0.22 sec.
# step  71/200, LF=0.352, done in  2 iter, after 0.23 sec.
# step  72/200, LF=0.357, done in  2 iter, after 0.23 sec.
# step  73/200, LF=0.362, done in  2 iter, after 0.23 sec.
# step  74/200, LF=0.367, done in  2 iter, after 0.22 sec.
# step  75/200, LF=0.372, done in  2 iter, after 0.22 sec.
# step  76/200, LF=0.377, done in  2 iter, after 0.22 sec.
# step  77/200, LF=0.382, done in  2 iter, after 0.23 sec.
# step  78/200, LF=0.387, done in  2 iter, after 0.23 sec.
# step  79/200, LF=0.392, done in  2 iter, after 0.34 sec.
# step  80/200, LF=0.397, done in  2 iter, after 0.20 sec.
# step  81/200, LF=0.402, done in  2 iter, after 0.23 sec.
# step  82/200, LF=0.407, done in  2 iter, after 0.23 sec.
# step  83/200, LF=0.412, done in  2 iter, after 0.23 sec.
# step  84/200, LF=0.417, done in  2 iter, after 0.22 sec.
# step  85/200, LF=0.422, done in  2 iter, after 0.23 sec.
# step  86/200, LF=0.427, done in  2 iter, after 0.23 sec.
# step  87/200, LF=0.432, done in  2 iter, after 0.29 sec.
# step  88/200, LF=0.437, done in  2 iter, after 0.23 sec.
# step  89/200, LF=0.442, done in  2 iter, after 0.23 sec.
# step  90/200, LF=0.447, done in  2 iter, after 0.22 sec.
# step  91/200, LF=0.452, done in  2 iter, after 0.23 sec.
# step  92/200, LF=0.457, done in  2 iter, after 0.23 sec.
# step  93/200, LF=0.462, done in  2 iter, after 0.23 sec.
# step  94/200, LF=0.467, done in  2 iter, after 0.23 sec.
# step  95/200, LF=0.472, done in  2 iter, after 0.23 sec.
# step  96/200, LF=0.477, done in  2 iter, after 0.23 sec.
# step  97/200, LF=0.482, done in  2 iter, after 0.23 sec.
# step  98/200, LF=0.487, done in  2 iter, after 0.23 sec.
# step  99/200, LF=0.492, done in  2 iter, after 0.22 sec.
# step 100/200, LF=0.497, done in  2 iter, after 0.23 sec.
# step 101/200, LF=0.503, done in  2 iter, after 0.23 sec.
# step 102/200, LF=0.508, done in  2 iter, after 0.35 sec.
# step 103/200, LF=0.513, done in  2 iter, after 0.22 sec.
# step 104/200, LF=0.518, done in  2 iter, after 0.23 sec.
# step 105/200, LF=0.523, done in  2 iter, after 0.23 sec.
# step 106/200, LF=0.528, done in  2 iter, after 0.24 sec.
# step 107/200, LF=0.533, done in  2 iter, after 0.25 sec.
# step 108/200, LF=0.538, done in  2 iter, after 0.32 sec.
# step 109/200, LF=0.543, done in  2 iter, after 0.38 sec.
# step 110/200, LF=0.548, done in  2 iter, after 0.42 sec.
# step 111/200, LF=0.553, done in  2 iter, after 0.33 sec.
# step 112/200, LF=0.558, done in  2 iter, after 0.24 sec.
# step 113/200, LF=0.563, done in  2 iter, after 0.22 sec.
# step 114/200, LF=0.568, done in  2 iter, after 0.22 sec.
# step 115/200, LF=0.573, done in  2 iter, after 0.23 sec.
# step 116/200, LF=0.578, done in  2 iter, after 0.22 sec.
# step 117/200, LF=0.583, done in  2 iter, after 0.22 sec.
# step 118/200, LF=0.588, done in  2 iter, after 0.22 sec.
# step 119/200, LF=0.593, done in  2 iter, after 0.22 sec.
# step 120/200, LF=0.598, done in  2 iter, after 0.23 sec.
# step 121/200, LF=0.603, done in  2 iter, after 0.22 sec.
# step 122/200, LF=0.608, done in  2 iter, after 0.23 sec.
# step 123/200, LF=0.613, done in  2 iter, after 0.23 sec.
# step 124/200, LF=0.618, done in  2 iter, after 0.22 sec.
# step 125/200, LF=0.623, done in  2 iter, after 0.34 sec.
# step 126/200, LF=0.628, done in  2 iter, after 0.24 sec.
# step 127/200, LF=0.633, done in  2 iter, after 0.24 sec.
# step 128/200, LF=0.638, done in  2 iter, after 0.25 sec.
# step 129/200, LF=0.643, done in  2 iter, after 0.24 sec.
# step 130/200, LF=0.648, done in  2 iter, after 0.25 sec.
# step 131/200, LF=0.653, done in  2 iter, after 0.24 sec.
# step 132/200, LF=0.658, done in  2 iter, after 0.24 sec.
# step 133/200, LF=0.663, done in  2 iter, after 0.24 sec.
# step 134/200, LF=0.668, done in  2 iter, after 0.24 sec.
# step 135/200, LF=0.673, done in  2 iter, after 0.24 sec.
# step 136/200, LF=0.678, done in  2 iter, after 0.24 sec.
# step 137/200, LF=0.683, done in  2 iter, after 0.24 sec.
# step 138/200, LF=0.688, done in  2 iter, after 0.25 sec.
# step 139/200, LF=0.693, done in  2 iter, after 0.26 sec.
# step 140/200, LF=0.698, done in  2 iter, after 0.25 sec.
# step 141/200, LF=0.704, done in  2 iter, after 0.24 sec.
# step 142/200, LF=0.709, done in  2 iter, after 0.24 sec.
# step 143/200, LF=0.714, done in  2 iter, after 0.24 sec.
# step 144/200, LF=0.719, done in  2 iter, after 0.25 sec.
# step 145/200, LF=0.724, done in  2 iter, after 0.28 sec.
# step 146/200, LF=0.729, done in  2 iter, after 0.25 sec.
# step 147/200, LF=0.734, done in  2 iter, after 0.25 sec.
# step 148/200, LF=0.739, done in  2 iter, after 0.36 sec.
# step 149/200, LF=0.744, done in  2 iter, after 0.24 sec.
# step 150/200, LF=0.749, done in  2 iter, after 0.24 sec.
# step 151/200, LF=0.754, done in  2 iter, after 0.24 sec.
# step 152/200, LF=0.759, done in  2 iter, after 0.24 sec.
# step 153/200, LF=0.764, done in  2 iter, after 0.24 sec.
# step 154/200, LF=0.769, done in  2 iter, after 0.24 sec.
# step 155/200, LF=0.774, done in  2 iter, after 0.22 sec.
# step 156/200, LF=0.779, done in  2 iter, after 0.24 sec.
# step 157/200, LF=0.784, done in  2 iter, after 0.24 sec.
# step 158/200, LF=0.789, done in  2 iter, after 0.24 sec.
# step 159/200, LF=0.794, done in  2 iter, after 0.25 sec.
# step 160/200, LF=0.799, done in  2 iter, after 0.25 sec.
# step 161/200, LF=0.804, done in  2 iter, after 0.25 sec.
# step 162/200, LF=0.809, done in  2 iter, after 0.25 sec.
# step 163/200, LF=0.814, done in  2 iter, after 0.26 sec.
# step 164/200, LF=0.819, done in  2 iter, after 0.24 sec.
# step 165/200, LF=0.824, done in  2 iter, after 0.25 sec.
# step 166/200, LF=0.829, done in  2 iter, after 0.25 sec.
# step 167/200, LF=0.834, done in  2 iter, after 0.24 sec.
# step 168/200, LF=0.839, done in  2 iter, after 0.24 sec.
# step 169/200, LF=0.844, done in  2 iter, after 0.24 sec.
# step 170/200, LF=0.849, done in  2 iter, after 0.24 sec.
# step 171/200, LF=0.854, done in  2 iter, after 0.35 sec.
# step 172/200, LF=0.859, done in  2 iter, after 0.24 sec.
# step 173/200, LF=0.864, done in  2 iter, after 0.24 sec.
# step 174/200, LF=0.869, done in  2 iter, after 0.24 sec.
# step 175/200, LF=0.874, done in  2 iter, after 0.24 sec.
# step 176/200, LF=0.879, done in  2 iter, after 0.24 sec.
# step 177/200, LF=0.884, done in  2 iter, after 0.24 sec.
# step 178/200, LF=0.889, done in  2 iter, after 0.24 sec.
# step 179/200, LF=0.894, done in  2 iter, after 0.24 sec.
# step 180/200, LF=0.899, done in  2 iter, after 0.24 sec.
# step 181/200, LF=0.905, done in  2 iter, after 0.24 sec.
# step 182/200, LF=0.910, done in  2 iter, after 0.24 sec.
# step 183/200, LF=0.915, done in  2 iter, after 0.25 sec.
# step 184/200, LF=0.920, done in  2 iter, after 0.25 sec.
# step 185/200, LF=0.925, done in  2 iter, after 0.25 sec.
# step 186/200, LF=0.930, done in  2 iter, after 0.26 sec.
# step 187/200, LF=0.935, done in  2 iter, after 0.26 sec.
# step 188/200, LF=0.940, done in  2 iter, after 0.25 sec.
# step 189/200, LF=0.945, done in  2 iter, after 0.25 sec.
# step 190/200, LF=0.950, done in  2 iter, after 0.25 sec.
# step 191/200, LF=0.955, done in  2 iter, after 0.25 sec.
# step 192/200, LF=0.960, done in  2 iter, after 0.25 sec.
# step 193/200, LF=0.965, done in  2 iter, after 0.25 sec.
# step 194/200, LF=0.970, done in  2 iter, after 0.40 sec.
# step 195/200, LF=0.975, done in  2 iter, after 0.22 sec.
# step 196/200, LF=0.980, done in  2 iter, after 0.25 sec.
# step 197/200, LF=0.985, done in  2 iter, after 0.25 sec.
# step 198/200, LF=0.990, done in  2 iter, after 0.25 sec.
# step 199/200, LF=0.995, done in  2 iter, after 0.25 sec.
# step 200/200, LF=1.000, done in  2 iter, after 0.25 sec.
# completed in 47 seconds
#  48.820694 seconds (56.41 M allocations: 51.243 GiB, 8.53% gc time, 2.36% compilation time)

# %%
cfig, ax = PyPlot.subplots()

plot_model(elems, nodes, cfig=cfig, ax=ax, 
  u=allus_d[end][1], Φ=get_I1(elems, allus_d[end][1]).-3)
;
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)

# %% [markdown]
# ## Plot some of the results

# %%
cfig, ax = PyPlot.subplots(2,1)


plot_model(elems, nodes, cfig=cfig, ax=ax[1], 
  u=allus_d[end][1], Φ=get_I1(elems, allus_d[end][1]).-3)
ax[1].plot(pos0[1,:]+allus_d[end][1][1,id_srtd],
  pos0[2,:]+allus_d[end][1][2,id_srtd], color=:b)        

plot_model(elems, nodes, cfig=cfig, ax=ax[2], 
  u=allus_e[end][1], Φ=get_I1(elems, allus_e[end][1]).-3)
ax[1].set_xlim([15, 85]); ax[1].set_ylim([-26, 10])
ax[1].set_title("with internal volume constraint, \$I_1-3\$")
ax[1].set_xticks([]); ax[1].set_yticks([])

ax[2].plot(pos0[1,:]+allus_e[end][1][1,id_srtd],
  pos0[2,:]+allus_e[end][1][2,id_srtd], color=:b)        
ax[2].set_xlim([15, 85]); ax[2].set_ylim([-26, 10])
ax[2].set_title("without internal volume constraint, \$I_1-3\$")
ax[2].set_xticks([]); ax[2].set_yticks([])

cfig.tight_layout(pad=2.0, w_pad=2.0, h_pad=2.0)


rf_tot_d = [sum(item[2][2, id_top])  for item in allus_d]
Δu_tot_d = [mean(item[1][2,id_top])  for item in allus_d]

rf_tot_e = [sum(item[2][2, id_top])  for item in allus_e]
Δu_tot_e = [mean(item[1][2,id_top])  for item in allus_e]

cfig, ax = PyPlot.subplots()
ax.plot(Δu_tot_d/50, rf_tot_d/1e5, color=:r)
ax.plot(Δu_tot_e/50, rf_tot_e/1e5, color=:b)
ax.set_xlabel("\$\\Delta u_2/L_2\$")
ax.set_ylabel("\$F_2\\times10^{-5}\$")
ax.set_title("Total reaction force")
;
# Out:
# Figure(PyObject <Figure size 640x480 with 4 Axes>)
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
