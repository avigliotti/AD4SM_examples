# %%
using LinearAlgebra, Printf
using AbaqusReader, Logging
using AD4SM

# %%
mean(x)   = sum(x)/length(x)

sMeshFile = "3DSpringHexaj.inp" 
mat       = Materials.NeoHooke(10. , 1e3)
bisinc    = true
sVTKpath  = "./vtk_files/"
bVTKall   = true
Δz        = 250 
sPosFix   = "_1e3w250"
sFileName = splitext(sMeshFile)[1]*sPosFix
N         = 300 
LF        = vcat(range(0.0, 0.7, length=N÷3),
                 range(0.7, 1.0, length=2N÷3+1))
nSteps    = length(LF)

mymodel   = with_logger(Logging.NullLogger()) do
  AbaqusReader.abaqus_read_mesh(sMeshFile)
end
nodes     = [mymodel["nodes"][ii] for ii in 1:mymodel["nodes"].count]
el_nodes  = [item[2]              for item in mymodel["elements"]] 
id_b      = mymodel["node_sets"]["BTM"]
id_t      = mymodel["node_sets"]["TOP"]
n_t, n_b  = length(id_t), length(id_b)

elems     = [Elements.Hex08(item, nodes[item], mat=mat)  for item in el_nodes]
;

# %%
@show nNodes, nElems   = length(nodes), length(elems)
@printf("starting %s \n\n", sFileName) 

ifree = trues(3, nNodes)  
unew  = zeros(3, nNodes)
λnew  = zeros(6)
idxes = LinearIndices(unew)
fnew  = zeros(3, nNodes)
allus = []
t0    = Base.time_ns()

for (ii,LF) in enumerate(LF)
  global unew, λnew, fnew
  w0    = LF*Δz 
  @printf("doing step %3i/%i, LF = %.4f, w0 = %.3f \n", 
          ii, nSteps, LF, w0); flush(stdout)

  eqns  = [Solvers.ConstEq(x->sum(x),          idxes[1,id_t][:], adiff.D1),
           Solvers.ConstEq(x->sum(x),          idxes[2,id_t][:], adiff.D1),
           Solvers.ConstEq(x->sum(x)/n_t-w0/2, idxes[3,id_t][:], adiff.D1),
           Solvers.ConstEq(x->sum(x),          idxes[1,id_b][:], adiff.D1),
           Solvers.ConstEq(x->sum(x),          idxes[2,id_b][:], adiff.D1),
           Solvers.ConstEq(x->sum(x)/n_b+w0/2, idxes[3,id_b][:], adiff.D1) ]

  lastu = copy(unew)
  lastλ = copy(λnew)
  fnew  = zeros(3, nNodes)
  T     = @elapsed (bfailed, normr, iter) = 
  Solvers.solvestep!(elems, lastu, unew, ifree, 
                      eqns      = eqns,
                      λ         = λnew,
                      fe        = fnew, 
                      dTolu     = 1e-4,
                      dTole     = 1e-3,
                      dNoise    = 1e-9,
                      bpredict  = false,
                      becho     = true)
  if bfailed 
    @printf("!! failed at LF: %.3f, with normr: %.3e\n\n", LF, normr)
    unew = lastu
    λnew = lastλ
    break
  else
    push!(allus, (copy(unew), copy(fnew), copy(λnew)))
    @printf("step %2i done in %2i iter, after %.2f sec.\n\n", ii, iter, T)
  end
  flush(stdout)
end
@printf("completed in %i seconds\n",(Base.time_ns()-t0)÷1e9)
flush(stdout)

Δu_tot = [mean(item[1][3,id_b]) for item in allus]
rf_tot = [item[3][3]            for item in allus]

;
# Out:
# (nNodes, nElems) = (length(nodes), length(elems)) = (6042, 4582)
# starting 3DSpringHexaj_1e3w250
#
# doing step   1/301, LF = 0.0000, w0 = 0.000
# iter:  0, norm0: 0.00e+00, normru: 0.00e+00, normre: 0.00e+00, eltime: 11.97 sec.
# step  1 done in  1 iter, after 16.65 sec.
#
# doing step   2/301, LF = 0.0071, w0 = 1.768
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.82e-01, α:    NaN, eltime: 2.35 sec.
# iter:  1, norm0: 0.00e+00, normru: 4.68e-03, normre: 3.78e-10, normupdt: 9.06e-03, α:  0.379, eltime: 1.96 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.84e-06, normre: 2.61e-12, eltime: 1.70 sec.
# step  2 done in  3 iter, after 6.22 sec.
#
# doing step   3/301, LF = 0.0141, w0 = 3.535
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.81e-01, α:    NaN, eltime: 1.99 sec.
# iter:  1, norm0: 0.00e+00, normru: 4.07e-03, normre: 1.38e-10, normupdt: 7.91e-03, α:  0.468, eltime: 2.03 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.43e-06, normre: 3.36e-12, eltime: 1.55 sec.
# step  3 done in  3 iter, after 5.57 sec.
#
# doing step   4/301, LF = 0.0212, w0 = 5.303
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.81e-01, α:    NaN, eltime: 1.79 sec.
# iter:  1, norm0: 0.00e+00, normru: 4.05e-03, normre: 1.90e-10, normupdt: 7.83e-03, α:  0.501, eltime: 2.00 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.42e-06, normre: 3.09e-12, eltime: 1.58 sec.
# step  4 done in  3 iter, after 5.37 sec.
#
# doing step   5/301, LF = 0.0283, w0 = 7.071
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.81e-01, α:    NaN, eltime: 1.82 sec.
# iter:  1, norm0: 0.00e+00, normru: 4.01e-03, normre: 3.26e-10, normupdt: 7.70e-03, α:  0.524, eltime: 2.18 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.39e-06, normre: 2.10e-12, eltime: 1.39 sec.
# step  5 done in  3 iter, after 5.39 sec.
#
# doing step   6/301, LF = 0.0354, w0 = 8.838
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.80e-01, α:    NaN, eltime: 1.94 sec.
# iter:  1, norm0: 0.00e+00, normru: 3.97e-03, normre: 1.00e-10, normupdt: 7.58e-03, α:  0.547, eltime: 1.93 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.36e-06, normre: 3.44e-12, eltime: 1.50 sec.
# step  6 done in  3 iter, after 5.37 sec.
#
# doing step   7/301, LF = 0.0424, w0 = 10.606
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.79e-01, α:    NaN, eltime: 1.78 sec.
# iter:  1, norm0: 0.00e+00, normru: 3.92e-03, normre: 2.60e-10, normupdt: 7.46e-03, α:  0.568, eltime: 2.20 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.33e-06, normre: 1.76e-12, eltime: 1.41 sec.
# step  7 done in  3 iter, after 5.39 sec.
#
# doing step   8/301, LF = 0.0495, w0 = 12.374
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.79e-01, α:    NaN, eltime: 2.01 sec.
# iter:  1, norm0: 0.00e+00, normru: 3.87e-03, normre: 4.25e-10, normupdt: 7.32e-03, α:  0.587, eltime: 2.38 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.30e-06, normre: 3.69e-12, eltime: 1.58 sec.
# step  8 done in  3 iter, after 5.96 sec.
#
# doing step   9/301, LF = 0.0566, w0 = 14.141
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.78e-01, α:    NaN, eltime: 1.79 sec.
# iter:  1, norm0: 0.00e+00, normru: 3.82e-03, normre: 7.48e-11, normupdt: 7.17e-03, α:  0.605, eltime: 2.21 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.26e-06, normre: 3.06e-12, eltime: 1.39 sec.
# step  9 done in  3 iter, after 5.40 sec.
#
# doing step  10/301, LF = 0.0636, w0 = 15.909
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.77e-01, α:    NaN, eltime: 1.89 sec.
# iter:  1, norm0: 0.00e+00, normru: 3.76e-03, normre: 2.80e-10, normupdt: 7.01e-03, α:  0.622, eltime: 2.54 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.23e-06, normre: 1.13e-12, eltime: 1.84 sec.
# step 10 done in  3 iter, after 6.26 sec.
#
# doing step  11/301, LF = 0.0707, w0 = 17.677
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.76e-01, α:    NaN, eltime: 1.77 sec.
# iter:  1, norm0: 0.00e+00, normru: 3.70e-03, normre: 1.82e-10, normupdt: 6.84e-03, α:  0.637, eltime: 2.08 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.19e-06, normre: 2.70e-12, eltime: 1.56 sec.
# step 11 done in  3 iter, after 5.41 sec.
#
# doing step  12/301, LF = 0.0778, w0 = 19.444
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.75e-01, α:    NaN, eltime: 1.82 sec.
# iter:  1, norm0: 0.00e+00, normru: 3.64e-03, normre: 4.75e-10, normupdt: 6.66e-03, α:  0.651, eltime: 2.10 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.14e-06, normre: 4.72e-12, eltime: 1.57 sec.
# step 12 done in  3 iter, after 5.49 sec.
#
# doing step  13/301, LF = 0.0848, w0 = 21.212
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.75e-01, α:    NaN, eltime: 2.03 sec.
# iter:  1, norm0: 0.00e+00, normru: 3.56e-03, normre: 3.00e-10, normupdt: 6.46e-03, α:  0.664, eltime: 2.12 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.10e-06, normre: 3.66e-12, eltime: 1.57 sec.
# step 13 done in  3 iter, after 5.72 sec.
#
# doing step  14/301, LF = 0.0919, w0 = 22.980
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.74e-01, α:    NaN, eltime: 1.81 sec.
# iter:  1, norm0: 0.00e+00, normru: 3.49e-03, normre: 2.52e-10, normupdt: 6.25e-03, α:  0.676, eltime: 2.08 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.06e-06, normre: 2.72e-12, eltime: 1.60 sec.
# step 14 done in  3 iter, after 5.50 sec.
#
# doing step  15/301, LF = 0.0990, w0 = 24.747
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.73e-01, α:    NaN, eltime: 1.84 sec.
# iter:  1, norm0: 0.00e+00, normru: 3.41e-03, normre: 1.43e-10, normupdt: 6.04e-03, α:  0.688, eltime: 2.38 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.01e-06, normre: 1.98e-12, eltime: 1.56 sec.
# step 15 done in  3 iter, after 5.79 sec.
#
# doing step  16/301, LF = 0.1061, w0 = 26.515
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.73e-01, α:    NaN, eltime: 1.81 sec.
# iter:  1, norm0: 0.00e+00, normru: 3.33e-03, normre: 3.76e-10, normupdt: 5.81e-03, α:  0.698, eltime: 2.20 sec.
# iter:  2, norm0: 0.00e+00, normru: 9.60e-07, normre: 2.39e-12, eltime: 1.60 sec.
# step 16 done in  3 iter, after 5.62 sec.
#
# doing step  17/301, LF = 0.1131, w0 = 28.283
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.72e-01, α:    NaN, eltime: 2.02 sec.
# iter:  1, norm0: 0.00e+00, normru: 3.24e-03, normre: 2.04e-10, normupdt: 5.58e-03, α:  0.707, eltime: 2.15 sec.
# iter:  2, norm0: 0.00e+00, normru: 9.11e-07, normre: 6.46e-12, eltime: 1.55 sec.
# step 17 done in  3 iter, after 5.73 sec.
#
# doing step  18/301, LF = 0.1202, w0 = 30.051
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.71e-01, α:    NaN, eltime: 1.92 sec.
# iter:  1, norm0: 0.00e+00, normru: 3.15e-03, normre: 4.75e-10, normupdt: 5.34e-03, α:  0.716, eltime: 2.88 sec.
# iter:  2, norm0: 0.00e+00, normru: 8.62e-07, normre: 4.54e-12, eltime: 1.42 sec.
# step 18 done in  3 iter, after 6.23 sec.
#
# doing step  19/301, LF = 0.1273, w0 = 31.818
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.70e-01, α:    NaN, eltime: 1.85 sec.
# iter:  1, norm0: 0.00e+00, normru: 3.06e-03, normre: 8.06e-10, normupdt: 5.09e-03, α:  0.724, eltime: 2.13 sec.
# iter:  2, norm0: 0.00e+00, normru: 8.13e-07, normre: 1.06e-11, eltime: 1.54 sec.
# step 19 done in  3 iter, after 5.52 sec.
#
# doing step  20/301, LF = 0.1343, w0 = 33.586
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.68e-01, α:    NaN, eltime: 1.78 sec.
# iter:  1, norm0: 0.00e+00, normru: 2.96e-03, normre: 7.89e-11, normupdt: 4.83e-03, α:  0.732, eltime: 2.21 sec.
# iter:  2, norm0: 0.00e+00, normru: 7.63e-07, normre: 3.35e-12, eltime: 1.41 sec.
# step 20 done in  3 iter, after 5.40 sec.
#
# doing step  21/301, LF = 0.1414, w0 = 35.354
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.67e-01, α:    NaN, eltime: 1.87 sec.
# iter:  1, norm0: 0.00e+00, normru: 2.87e-03, normre: 1.66e-10, normupdt: 4.58e-03, α:  0.738, eltime: 2.05 sec.
# iter:  2, norm0: 0.00e+00, normru: 7.15e-07, normre: 2.23e-12, eltime: 1.83 sec.
# step 21 done in  3 iter, after 5.75 sec.
#
# doing step  22/301, LF = 0.1485, w0 = 37.121
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.66e-01, α:    NaN, eltime: 2.25 sec.
# iter:  1, norm0: 0.00e+00, normru: 2.77e-03, normre: 2.31e-10, normupdt: 4.32e-03, α:  0.745, eltime: 2.62 sec.
# iter:  2, norm0: 0.00e+00, normru: 6.67e-07, normre: 2.48e-12, eltime: 1.91 sec.
# step 22 done in  3 iter, after 6.78 sec.
#
# doing step  23/301, LF = 0.1556, w0 = 38.889
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.64e-01, α:    NaN, eltime: 2.13 sec.
# iter:  1, norm0: 0.00e+00, normru: 2.67e-03, normre: 3.83e-10, normupdt: 4.06e-03, α:  0.750, eltime: 2.48 sec.
# iter:  2, norm0: 0.00e+00, normru: 6.21e-07, normre: 8.81e-12, eltime: 1.87 sec.
# step 23 done in  3 iter, after 6.49 sec.
#
# doing step  24/301, LF = 0.1626, w0 = 40.657
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.63e-01, α:    NaN, eltime: 2.13 sec.
# iter:  1, norm0: 0.00e+00, normru: 2.57e-03, normre: 2.77e-10, normupdt: 3.81e-03, α:  0.756, eltime: 2.66 sec.
# iter:  2, norm0: 0.00e+00, normru: 5.76e-07, normre: 6.80e-12, eltime: 1.91 sec.
# step 24 done in  3 iter, after 6.70 sec.
#
# doing step  25/301, LF = 0.1697, w0 = 42.424
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.61e-01, α:    NaN, eltime: 2.40 sec.
# iter:  1, norm0: 0.00e+00, normru: 2.48e-03, normre: 3.91e-10, normupdt: 3.56e-03, α:  0.760, eltime: 3.70 sec.
# iter:  2, norm0: 0.00e+00, normru: 5.33e-07, normre: 2.68e-12, eltime: 2.08 sec.
# step 25 done in  3 iter, after 8.18 sec.
#
# doing step  26/301, LF = 0.1768, w0 = 44.192
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.59e-01, α:    NaN, eltime: 2.02 sec.
# iter:  1, norm0: 0.00e+00, normru: 2.38e-03, normre: 3.85e-10, normupdt: 3.31e-03, α:  0.764, eltime: 2.09 sec.
# iter:  2, norm0: 0.00e+00, normru: 4.93e-07, normre: 1.77e-12, eltime: 1.53 sec.
# step 26 done in  3 iter, after 5.64 sec.
#
# doing step  27/301, LF = 0.1838, w0 = 45.960
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.58e-01, α:    NaN, eltime: 1.90 sec.
# iter:  1, norm0: 0.00e+00, normru: 2.29e-03, normre: 2.83e-10, normupdt: 3.11e-03, α:  0.767, eltime: 2.15 sec.
# iter:  2, norm0: 0.00e+00, normru: 4.54e-07, normre: 5.97e-12, eltime: 1.56 sec.
# step 27 done in  3 iter, after 5.62 sec.
#
# doing step  28/301, LF = 0.1909, w0 = 47.727
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.56e-01, α:    NaN, eltime: 1.78 sec.
# iter:  1, norm0: 0.00e+00, normru: 2.20e-03, normre: 5.03e-10, normupdt: 3.06e-03, α:  0.769, eltime: 2.15 sec.
# iter:  2, norm0: 0.00e+00, normru: 4.18e-07, normre: 9.79e-12, eltime: 1.52 sec.
# step 28 done in  3 iter, after 5.45 sec.
#
# doing step  29/301, LF = 0.1980, w0 = 49.495
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.54e-01, α:    NaN, eltime: 1.82 sec.
# iter:  1, norm0: 0.00e+00, normru: 2.11e-03, normre: 1.30e-10, normupdt: 3.00e-03, α:  0.770, eltime: 2.14 sec.
# iter:  2, norm0: 0.00e+00, normru: 3.85e-07, normre: 2.43e-12, eltime: 1.86 sec.
# step 29 done in  3 iter, after 5.82 sec.
#
# doing step  30/301, LF = 0.2051, w0 = 51.263
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.53e-01, α:    NaN, eltime: 2.48 sec.
# iter:  1, norm0: 0.00e+00, normru: 2.02e-03, normre: 4.17e-10, normupdt: 2.93e-03, α:  0.769, eltime: 2.41 sec.
# iter:  2, norm0: 0.00e+00, normru: 3.53e-07, normre: 4.20e-12, eltime: 1.45 sec.
# step 30 done in  3 iter, after 6.34 sec.
#
# doing step  31/301, LF = 0.2121, w0 = 53.030
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.51e-01, α:    NaN, eltime: 2.16 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.94e-03, normre: 5.46e-10, normupdt: 2.86e-03, α:  0.767, eltime: 1.93 sec.
# iter:  2, norm0: 0.00e+00, normru: 3.25e-07, normre: 4.86e-12, eltime: 1.51 sec.
# step 31 done in  3 iter, after 5.60 sec.
#
# doing step  32/301, LF = 0.2192, w0 = 54.798
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.49e-01, α:    NaN, eltime: 2.67 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.87e-03, normre: 5.48e-10, normupdt: 2.79e-03, α:  0.762, eltime: 2.21 sec.
# iter:  2, norm0: 0.00e+00, normru: 2.99e-07, normre: 4.59e-12, eltime: 1.67 sec.
# step 32 done in  3 iter, after 6.54 sec.
#
# doing step  33/301, LF = 0.2263, w0 = 56.566
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.47e-01, α:    NaN, eltime: 2.57 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.80e-03, normre: 8.17e-10, normupdt: 2.71e-03, α:  0.755, eltime: 2.47 sec.
# iter:  2, norm0: 0.00e+00, normru: 2.75e-07, normre: 5.83e-12, eltime: 1.80 sec.
# step 33 done in  3 iter, after 6.84 sec.
#
# doing step  34/301, LF = 0.2333, w0 = 58.333
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.46e-01, α:    NaN, eltime: 2.49 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.73e-03, normre: 3.69e-10, normupdt: 2.63e-03, α:  0.745, eltime: 2.41 sec.
# iter:  2, norm0: 0.00e+00, normru: 2.53e-07, normre: 6.67e-12, eltime: 1.79 sec.
# step 34 done in  3 iter, after 6.69 sec.
#
# doing step  35/301, LF = 0.2404, w0 = 60.101
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.44e-01, α:    NaN, eltime: 2.46 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.67e-03, normre: 3.64e-10, normupdt: 2.55e-03, α:  0.731, eltime: 2.38 sec.
# iter:  2, norm0: 0.00e+00, normru: 2.34e-07, normre: 2.74e-12, eltime: 1.96 sec.
# step 35 done in  3 iter, after 6.79 sec.
#
# doing step  36/301, LF = 0.2475, w0 = 61.869
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.43e-01, α:    NaN, eltime: 3.33 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.61e-03, normre: 6.82e-10, normupdt: 2.47e-03, α:  0.713, eltime: 1.94 sec.
# iter:  2, norm0: 0.00e+00, normru: 2.16e-07, normre: 6.37e-12, eltime: 1.42 sec.
# step 36 done in  3 iter, after 6.69 sec.
#
# doing step  37/301, LF = 0.2545, w0 = 63.636
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.42e-01, α:    NaN, eltime: 2.12 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.56e-03, normre: 4.57e-10, normupdt: 2.39e-03, α:  0.691, eltime: 2.01 sec.
# iter:  2, norm0: 0.00e+00, normru: 2.01e-07, normre: 4.95e-12, eltime: 1.49 sec.
# step 37 done in  3 iter, after 5.63 sec.
#
# doing step  38/301, LF = 0.2616, w0 = 65.404
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.40e-01, α:    NaN, eltime: 2.16 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.51e-03, normre: 2.70e-10, normupdt: 2.30e-03, α:  0.666, eltime: 1.93 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.87e-07, normre: 4.56e-12, eltime: 1.95 sec.
# step 38 done in  3 iter, after 6.03 sec.
#
# doing step  39/301, LF = 0.2687, w0 = 67.172
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.39e-01, α:    NaN, eltime: 2.68 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.47e-03, normre: 6.75e-10, normupdt: 2.21e-03, α:  0.636, eltime: 2.38 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.75e-07, normre: 1.43e-11, eltime: 1.94 sec.
# step 39 done in  3 iter, after 7.00 sec.
#
# doing step  40/301, LF = 0.2758, w0 = 68.939
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.38e-01, α:    NaN, eltime: 2.19 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.44e-03, normre: 1.51e-10, normupdt: 2.12e-03, α:  0.604, eltime: 1.85 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.65e-07, normre: 9.02e-13, eltime: 1.40 sec.
# step 40 done in  3 iter, after 5.44 sec.
#
# doing step  41/301, LF = 0.2828, w0 = 70.707
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.37e-01, α:    NaN, eltime: 2.03 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.41e-03, normre: 1.01e-09, normupdt: 2.04e-03, α:  0.569, eltime: 1.89 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.56e-07, normre: 1.46e-12, eltime: 1.40 sec.
# step 41 done in  3 iter, after 5.31 sec.
#
# doing step  42/301, LF = 0.2899, w0 = 72.475
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.36e-01, α:    NaN, eltime: 1.94 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.38e-03, normre: 4.34e-10, normupdt: 1.95e-03, α:  0.533, eltime: 2.02 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.49e-07, normre: 5.14e-12, eltime: 1.59 sec.
# step 42 done in  3 iter, after 5.56 sec.
#
# doing step  43/301, LF = 0.2970, w0 = 74.242
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.35e-01, α:    NaN, eltime: 2.04 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.36e-03, normre: 3.28e-10, normupdt: 1.86e-03, α:  0.496, eltime: 1.92 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.42e-07, normre: 8.69e-12, eltime: 1.65 sec.
# step 43 done in  3 iter, after 5.60 sec.
#
# doing step  44/301, LF = 0.3040, w0 = 76.010
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.34e-01, α:    NaN, eltime: 2.15 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.34e-03, normre: 7.59e-10, normupdt: 1.78e-03, α:  0.459, eltime: 2.40 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.37e-07, normre: 3.96e-12, eltime: 2.02 sec.
# step 44 done in  3 iter, after 6.57 sec.
#
# doing step  45/301, LF = 0.3111, w0 = 77.778
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.33e-01, α:    NaN, eltime: 2.23 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.33e-03, normre: 3.16e-10, normupdt: 1.70e-03, α:  0.423, eltime: 2.40 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.33e-07, normre: 1.41e-11, eltime: 1.81 sec.
# step 45 done in  3 iter, after 6.44 sec.
#
# doing step  46/301, LF = 0.3182, w0 = 79.545
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.32e-01, α:    NaN, eltime: 1.91 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.32e-03, normre: 6.62e-10, normupdt: 1.71e-03, α:  0.388, eltime: 2.15 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.30e-07, normre: 6.97e-12, eltime: 1.52 sec.
# step 46 done in  3 iter, after 5.58 sec.
#
# doing step  47/301, LF = 0.3253, w0 = 81.313
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.31e-01, α:    NaN, eltime: 1.83 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.31e-03, normre: 2.41e-10, normupdt: 1.79e-03, α:  0.355, eltime: 2.27 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.28e-07, normre: 1.18e-11, eltime: 1.36 sec.
# step 47 done in  3 iter, after 5.46 sec.
#
# doing step  48/301, LF = 0.3323, w0 = 83.081
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.30e-01, α:    NaN, eltime: 1.76 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.31e-03, normre: 7.28e-10, normupdt: 1.86e-03, α:  0.324, eltime: 2.11 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.27e-07, normre: 5.97e-12, eltime: 1.62 sec.
# step 48 done in  3 iter, after 5.50 sec.
#
# doing step  49/301, LF = 0.3394, w0 = 84.848
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.29e-01, α:    NaN, eltime: 1.84 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.31e-03, normre: 8.67e-10, normupdt: 1.93e-03, α:  0.294, eltime: 1.86 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.26e-07, normre: 8.21e-12, eltime: 1.52 sec.
# step 49 done in  3 iter, after 5.22 sec.
#
# doing step  50/301, LF = 0.3465, w0 = 86.616
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.28e-01, α:    NaN, eltime: 2.06 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.31e-03, normre: 6.82e-10, normupdt: 1.99e-03, α:  0.267, eltime: 1.87 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.26e-07, normre: 8.91e-12, eltime: 1.42 sec.
# step 50 done in  3 iter, after 5.35 sec.
#
# doing step  51/301, LF = 0.3535, w0 = 88.384
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.27e-01, α:    NaN, eltime: 1.98 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.32e-03, normre: 8.49e-10, normupdt: 2.04e-03, α:  0.242, eltime: 1.85 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.27e-07, normre: 2.25e-11, eltime: 1.57 sec.
# step 51 done in  3 iter, after 5.40 sec.
#
# doing step  52/301, LF = 0.3606, w0 = 90.152
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.27e-01, α:    NaN, eltime: 1.79 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.32e-03, normre: 4.69e-10, normupdt: 2.09e-03, α:  0.219, eltime: 2.07 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.28e-07, normre: 1.05e-11, eltime: 1.56 sec.
# step 52 done in  3 iter, after 5.42 sec.
#
# doing step  53/301, LF = 0.3677, w0 = 91.919
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.26e-01, α:    NaN, eltime: 2.15 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.33e-03, normre: 6.57e-10, normupdt: 2.13e-03, α:  0.197, eltime: 2.28 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.29e-07, normre: 8.41e-12, eltime: 1.62 sec.
# step 53 done in  3 iter, after 6.05 sec.
#
# doing step  54/301, LF = 0.3747, w0 = 93.687
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.25e-01, α:    NaN, eltime: 2.04 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.34e-03, normre: 5.47e-10, normupdt: 2.16e-03, α:  0.177, eltime: 2.31 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.31e-07, normre: 9.34e-12, eltime: 1.43 sec.
# step 54 done in  3 iter, after 5.78 sec.
#
# doing step  55/301, LF = 0.3818, w0 = 95.455
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.25e-01, α:    NaN, eltime: 1.81 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.36e-03, normre: 1.05e-10, normupdt: 2.19e-03, α:  0.159, eltime: 1.89 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.34e-07, normre: 4.64e-12, eltime: 1.70 sec.
# step 55 done in  3 iter, after 5.40 sec.
#
# doing step  56/301, LF = 0.3889, w0 = 97.222
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.24e-01, α:    NaN, eltime: 2.40 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.37e-03, normre: 1.60e-09, normupdt: 2.22e-03, α:  0.143, eltime: 2.44 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.37e-07, normre: 2.68e-11, eltime: 1.52 sec.
# step 56 done in  3 iter, after 6.37 sec.
#
# doing step  57/301, LF = 0.3960, w0 = 98.990
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.23e-01, α:    NaN, eltime: 1.99 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.39e-03, normre: 4.32e-10, normupdt: 2.24e-03, α:  0.128, eltime: 1.90 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.40e-07, normre: 1.67e-11, eltime: 1.39 sec.
# step 57 done in  3 iter, after 5.27 sec.
#
# doing step  58/301, LF = 0.4030, w0 = 100.758
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.23e-01, α:    NaN, eltime: 2.02 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.41e-03, normre: 6.55e-10, normupdt: 2.25e-03, α:  0.114, eltime: 1.85 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.44e-07, normre: 8.56e-12, eltime: 1.40 sec.
# step 58 done in  3 iter, after 5.27 sec.
#
# doing step  59/301, LF = 0.4101, w0 = 102.525
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.22e-01, α:    NaN, eltime: 2.04 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.43e-03, normre: 2.50e-10, normupdt: 2.26e-03, α:  0.101, eltime: 1.85 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.48e-07, normre: 8.56e-12, eltime: 1.74 sec.
# step 59 done in  3 iter, after 5.62 sec.
#
# doing step  60/301, LF = 0.4172, w0 = 104.293
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.22e-01, α:    NaN, eltime: 2.46 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.45e-03, normre: 9.28e-10, normupdt: 2.27e-03, α:  0.090, eltime: 1.89 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.52e-07, normre: 1.24e-11, eltime: 1.37 sec.
# step 60 done in  3 iter, after 5.73 sec.
#
# doing step  61/301, LF = 0.4242, w0 = 106.061
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.21e-01, α:    NaN, eltime: 2.04 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.47e-03, normre: 8.70e-10, normupdt: 2.28e-03, α:  0.080, eltime: 1.83 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.57e-07, normre: 1.32e-11, eltime: 1.38 sec.
# step 61 done in  3 iter, after 5.26 sec.
#
# doing step  62/301, LF = 0.4313, w0 = 107.828
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.21e-01, α:    NaN, eltime: 1.98 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.50e-03, normre: 6.05e-10, normupdt: 2.29e-03, α:  0.070, eltime: 2.09 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.62e-07, normre: 1.39e-11, eltime: 1.60 sec.
# step 62 done in  3 iter, after 5.67 sec.
#
# doing step  63/301, LF = 0.4384, w0 = 109.596
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.21e-01, α:    NaN, eltime: 1.87 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.53e-03, normre: 3.08e-10, normupdt: 2.29e-03, α:  0.062, eltime: 2.65 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.67e-07, normre: 1.75e-11, eltime: 1.54 sec.
# step 63 done in  3 iter, after 6.06 sec.
#
# doing step  64/301, LF = 0.4455, w0 = 111.364
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.20e-01, α:    NaN, eltime: 1.85 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.56e-03, normre: 7.98e-10, normupdt: 2.29e-03, α:  0.054, eltime: 2.00 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.73e-07, normre: 8.04e-12, eltime: 1.58 sec.
# step 64 done in  3 iter, after 5.44 sec.
#
# doing step  65/301, LF = 0.4525, w0 = 113.131
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.20e-01, α:    NaN, eltime: 1.83 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.59e-03, normre: 1.16e-09, normupdt: 2.29e-03, α:  0.048, eltime: 2.17 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.80e-07, normre: 2.44e-11, eltime: 1.51 sec.
# step 65 done in  3 iter, after 5.50 sec.
#
# doing step  66/301, LF = 0.4596, w0 = 114.899
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.20e-01, α:    NaN, eltime: 2.20 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.62e-03, normre: 1.31e-09, normupdt: 2.29e-03, α:  0.042, eltime: 2.69 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.87e-07, normre: 1.94e-11, eltime: 1.79 sec.
# step 66 done in  3 iter, after 6.69 sec.
#
# doing step  67/301, LF = 0.4667, w0 = 116.667
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.20e-01, α:    NaN, eltime: 2.22 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.66e-03, normre: 1.04e-09, normupdt: 2.29e-03, α:  0.037, eltime: 2.51 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.94e-07, normre: 2.37e-11, eltime: 2.10 sec.
# step 67 done in  3 iter, after 6.83 sec.
#
# doing step  68/301, LF = 0.4737, w0 = 118.434
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.20e-01, α:    NaN, eltime: 2.45 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.70e-03, normre: 3.56e-10, normupdt: 2.28e-03, α:  0.032, eltime: 2.59 sec.
# iter:  2, norm0: 0.00e+00, normru: 2.03e-07, normre: 3.03e-11, eltime: 1.72 sec.
# step 68 done in  3 iter, after 6.76 sec.
#
# doing step  69/301, LF = 0.4808, w0 = 120.202
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.19e-01, α:    NaN, eltime: 2.25 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.75e-03, normre: 9.09e-10, normupdt: 2.28e-03, α:  0.028, eltime: 2.48 sec.
# iter:  2, norm0: 0.00e+00, normru: 2.12e-07, normre: 8.99e-12, eltime: 1.82 sec.
# step 69 done in  3 iter, after 6.56 sec.
#
# doing step  70/301, LF = 0.4879, w0 = 121.970
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.19e-01, α:    NaN, eltime: 2.10 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.79e-03, normre: 1.00e-09, normupdt: 2.28e-03, α:  0.025, eltime: 2.76 sec.
# iter:  2, norm0: 0.00e+00, normru: 2.22e-07, normre: 1.08e-11, eltime: 2.65 sec.
# step 70 done in  3 iter, after 7.51 sec.
#
# doing step  71/301, LF = 0.4949, w0 = 123.737
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.19e-01, α:    NaN, eltime: 4.25 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.85e-03, normre: 1.60e-10, normupdt: 2.28e-03, α:  0.022, eltime: 3.85 sec.
# iter:  2, norm0: 0.00e+00, normru: 2.34e-07, normre: 7.30e-12, eltime: 2.42 sec.
# step 71 done in  3 iter, after 10.52 sec.
#
# doing step  72/301, LF = 0.5020, w0 = 125.505
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.19e-01, α:    NaN, eltime: 3.71 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.90e-03, normre: 8.56e-10, normupdt: 2.27e-03, α:  0.019, eltime: 3.70 sec.
# iter:  2, norm0: 0.00e+00, normru: 2.46e-07, normre: 6.44e-12, eltime: 3.15 sec.
# step 72 done in  3 iter, after 10.56 sec.
#
# doing step  73/301, LF = 0.5091, w0 = 127.273
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.19e-01, α:    NaN, eltime: 3.73 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.97e-03, normre: 1.64e-09, normupdt: 2.27e-03, α:  0.017, eltime: 4.44 sec.
# iter:  2, norm0: 0.00e+00, normru: 2.61e-07, normre: 4.27e-11, eltime: 2.97 sec.
# step 73 done in  3 iter, after 11.14 sec.
#
# doing step  74/301, LF = 0.5162, w0 = 129.040
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.19e-01, α:    NaN, eltime: 4.38 sec.
# iter:  1, norm0: 0.00e+00, normru: 2.04e-03, normre: 5.53e-10, normupdt: 2.27e-03, α:  0.015, eltime: 4.21 sec.
# iter:  2, norm0: 0.00e+00, normru: 2.77e-07, normre: 1.10e-11, eltime: 3.35 sec.
# step 74 done in  3 iter, after 11.94 sec.
#
# doing step  75/301, LF = 0.5232, w0 = 130.808
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.19e-01, α:    NaN, eltime: 4.09 sec.
# iter:  1, norm0: 0.00e+00, normru: 2.11e-03, normre: 1.68e-10, normupdt: 2.27e-03, α:  0.014, eltime: 4.19 sec.
# iter:  2, norm0: 0.00e+00, normru: 2.96e-07, normre: 1.67e-11, eltime: 2.98 sec.
# step 75 done in  3 iter, after 11.26 sec.
#
# doing step  76/301, LF = 0.5303, w0 = 132.576
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.19e-01, α:    NaN, eltime: 2.27 sec.
# iter:  1, norm0: 0.00e+00, normru: 2.20e-03, normre: 5.86e-10, normupdt: 2.28e-03, α:  0.013, eltime: 2.51 sec.
# iter:  2, norm0: 0.00e+00, normru: 3.17e-07, normre: 1.29e-11, eltime: 1.88 sec.
# step 76 done in  3 iter, after 6.66 sec.
#
# doing step  77/301, LF = 0.5374, w0 = 134.343
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.18e-01, α:    NaN, eltime: 2.09 sec.
# iter:  1, norm0: 0.00e+00, normru: 2.29e-03, normre: 6.25e-10, normupdt: 2.28e-03, α:  0.012, eltime: 2.57 sec.
# iter:  2, norm0: 0.00e+00, normru: 3.42e-07, normre: 7.96e-12, eltime: 1.71 sec.
# step 77 done in  3 iter, after 6.37 sec.
#
# doing step  78/301, LF = 0.5444, w0 = 136.111
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.18e-01, α:    NaN, eltime: 2.24 sec.
# iter:  1, norm0: 0.00e+00, normru: 2.40e-03, normre: 1.35e-09, normupdt: 2.29e-03, α:  0.011, eltime: 2.59 sec.
# iter:  2, norm0: 0.00e+00, normru: 3.71e-07, normre: 1.21e-11, eltime: 1.90 sec.
# step 78 done in  3 iter, after 6.72 sec.
#
# doing step  79/301, LF = 0.5515, w0 = 137.879
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.18e-01, α:    NaN, eltime: 2.14 sec.
# iter:  1, norm0: 0.00e+00, normru: 2.51e-03, normre: 1.25e-09, normupdt: 2.29e-03, α:  0.010, eltime: 2.65 sec.
# iter:  2, norm0: 0.00e+00, normru: 4.05e-07, normre: 3.85e-11, eltime: 1.73 sec.
# step 79 done in  3 iter, after 6.53 sec.
#
# doing step  80/301, LF = 0.5586, w0 = 139.646
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.18e-01, α:    NaN, eltime: 3.86 sec.
# iter:  1, norm0: 0.00e+00, normru: 2.64e-03, normre: 2.63e-09, normupdt: 2.30e-03, α:  0.009, eltime: 3.27 sec.
# iter:  2, norm0: 0.00e+00, normru: 4.45e-07, normre: 3.95e-11, eltime: 2.59 sec.
# step 80 done in  3 iter, after 9.72 sec.
#
# doing step  81/301, LF = 0.5657, w0 = 141.414
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.18e-01, α:    NaN, eltime: 3.44 sec.
# iter:  1, norm0: 0.00e+00, normru: 2.79e-03, normre: 7.68e-10, normupdt: 2.32e-03, α:  0.008, eltime: 3.83 sec.
# iter:  2, norm0: 0.00e+00, normru: 4.92e-07, normre: 9.89e-12, eltime: 2.96 sec.
# step 81 done in  3 iter, after 10.23 sec.
#
# doing step  82/301, LF = 0.5727, w0 = 143.182
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.18e-01, α:    NaN, eltime: 3.60 sec.
# iter:  1, norm0: 0.00e+00, normru: 2.95e-03, normre: 1.48e-09, normupdt: 2.39e-03, α:  0.007, eltime: 4.14 sec.
# iter:  2, norm0: 0.00e+00, normru: 5.48e-07, normre: 1.40e-11, eltime: 2.94 sec.
# step 82 done in  3 iter, after 10.69 sec.
#
# doing step  83/301, LF = 0.5798, w0 = 144.949
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.18e-01, α:    NaN, eltime: 3.89 sec.
# iter:  1, norm0: 0.00e+00, normru: 3.13e-03, normre: 2.43e-09, normupdt: 2.57e-03, α:  0.006, eltime: 3.97 sec.
# iter:  2, norm0: 0.00e+00, normru: 6.15e-07, normre: 3.50e-11, eltime: 2.93 sec.
# step 83 done in  3 iter, after 10.79 sec.
#
# doing step  84/301, LF = 0.5869, w0 = 146.717
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.18e-01, α:    NaN, eltime: 4.06 sec.
# iter:  1, norm0: 0.00e+00, normru: 3.33e-03, normre: 2.05e-09, normupdt: 2.77e-03, α:  0.004, eltime: 3.92 sec.
# iter:  2, norm0: 0.00e+00, normru: 6.96e-07, normre: 3.52e-11, eltime: 2.85 sec.
# step 84 done in  3 iter, after 10.82 sec.
#
# doing step  85/301, LF = 0.5939, w0 = 148.485
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.18e-01, α:    NaN, eltime: 2.51 sec.
# iter:  1, norm0: 0.00e+00, normru: 3.55e-03, normre: 1.94e-09, normupdt: 2.98e-03, α:  0.003, eltime: 2.42 sec.
# iter:  2, norm0: 0.00e+00, normru: 7.93e-07, normre: 4.76e-11, eltime: 1.87 sec.
# step 85 done in  3 iter, after 6.81 sec.
#
# doing step  86/301, LF = 0.6010, w0 = 150.253
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.18e-01, α:    NaN, eltime: 2.15 sec.
# iter:  1, norm0: 0.00e+00, normru: 3.80e-03, normre: 7.14e-10, normupdt: 3.21e-03, α:  0.001, eltime: 2.67 sec.
# iter:  2, norm0: 0.00e+00, normru: 9.11e-07, normre: 3.23e-11, eltime: 1.70 sec.
# step 86 done in  3 iter, after 6.52 sec.
#
# doing step  87/301, LF = 0.6081, w0 = 152.020
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.18e-01, α:    NaN, eltime: 1.91 sec.
# iter:  1, norm0: 0.00e+00, normru: 4.09e-03, normre: 7.92e-10, normupdt: 3.46e-03, α: -0.001, eltime: 2.26 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.05e-06, normre: 3.42e-11, eltime: 1.49 sec.
# step 87 done in  3 iter, after 5.66 sec.
#
# doing step  88/301, LF = 0.6152, w0 = 153.788
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.19e-01, α:    NaN, eltime: 1.96 sec.
# iter:  1, norm0: 0.00e+00, normru: 4.40e-03, normre: 2.10e-09, normupdt: 3.73e-03, α: -0.003, eltime: 2.66 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.23e-06, normre: 3.67e-11, eltime: 2.04 sec.
# step 88 done in  3 iter, after 6.67 sec.
#
# doing step  89/301, LF = 0.6222, w0 = 155.556
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.19e-01, α:    NaN, eltime: 2.44 sec.
# iter:  1, norm0: 0.00e+00, normru: 4.75e-03, normre: 1.09e-09, normupdt: 4.03e-03, α: -0.006, eltime: 2.59 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.43e-06, normre: 5.98e-11, eltime: 2.08 sec.
# step 89 done in  3 iter, after 7.11 sec.
#
# doing step  90/301, LF = 0.6293, w0 = 157.323
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.19e-01, α:    NaN, eltime: 2.25 sec.
# iter:  1, norm0: 0.00e+00, normru: 5.15e-03, normre: 3.45e-09, normupdt: 4.36e-03, α: -0.009, eltime: 2.43 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.69e-06, normre: 6.73e-11, eltime: 2.04 sec.
# step 90 done in  3 iter, after 6.72 sec.
#
# doing step  91/301, LF = 0.6364, w0 = 159.091
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.19e-01, α:    NaN, eltime: 2.25 sec.
# iter:  1, norm0: 0.00e+00, normru: 5.60e-03, normre: 3.73e-10, normupdt: 4.72e-03, α: -0.012, eltime: 2.42 sec.
# iter:  2, norm0: 0.00e+00, normru: 2.00e-06, normre: 1.90e-11, eltime: 1.82 sec.
# step 91 done in  3 iter, after 6.49 sec.
#
# doing step  92/301, LF = 0.6434, w0 = 160.859
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.19e-01, α:    NaN, eltime: 2.30 sec.
# iter:  1, norm0: 0.00e+00, normru: 6.09e-03, normre: 1.22e-09, normupdt: 5.12e-03, α: -0.016, eltime: 2.76 sec.
# iter:  2, norm0: 0.00e+00, normru: 2.39e-06, normre: 5.98e-11, eltime: 2.01 sec.
# step 92 done in  3 iter, after 7.07 sec.
#
# doing step  93/301, LF = 0.6505, w0 = 162.626
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.19e-01, α:    NaN, eltime: 2.57 sec.
# iter:  1, norm0: 0.00e+00, normru: 6.65e-03, normre: 1.58e-09, normupdt: 5.59e-03, α: -0.020, eltime: 2.35 sec.
# iter:  2, norm0: 0.00e+00, normru: 2.86e-06, normre: 9.55e-11, eltime: 2.03 sec.
# step 93 done in  3 iter, after 6.95 sec.
#
# doing step  94/301, LF = 0.6576, w0 = 164.394
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.20e-01, α:    NaN, eltime: 2.18 sec.
# iter:  1, norm0: 0.00e+00, normru: 7.29e-03, normre: 3.31e-10, normupdt: 6.16e-03, α: -0.024, eltime: 2.69 sec.
# iter:  2, norm0: 0.00e+00, normru: 3.44e-06, normre: 4.51e-11, eltime: 1.87 sec.
# step 94 done in  3 iter, after 6.74 sec.
#
# doing step  95/301, LF = 0.6646, w0 = 166.162
# iter:  0, norm0: 0.00e+00, normru: 6.90e-05, normre: 8.84e-01, normupdt: 9.20e-01, α:    NaN, eltime: 2.46 sec.
# iter:  1, norm0: 0.00e+00, normru: 8.03e-03, normre: 2.44e-09, normupdt: 6.98e-03, α: -0.030, eltime: 3.01 sec.
# iter:  2, norm0: 0.00e+00, normru: 4.24e-06, normre: 6.32e-11, eltime: 2.12 sec.
# step 95 done in  3 iter, after 7.60 sec.
#
# doing step  96/301, LF = 0.6717, w0 = 167.929
# iter:  0, norm0: 0.00e+00, normru: 6.91e-05, normre: 8.84e-01, normupdt: 9.20e-01, α:    NaN, eltime: 2.92 sec.
# iter:  1, norm0: 0.00e+00, normru: 9.20e-03, normre: 9.95e-10, normupdt: 8.59e-03, α: -0.040, eltime: 3.05 sec.
# iter:  2, norm0: 0.00e+00, normru: 5.90e-06, normre: 9.56e-11, eltime: 2.25 sec.
# step 96 done in  3 iter, after 8.23 sec.
#
# doing step  97/301, LF = 0.6788, w0 = 169.697
# iter:  0, norm0: 0.00e+00, normru: 6.92e-05, normre: 8.84e-01, normupdt: 9.20e-01, α:    NaN, eltime: 3.02 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.28e-02, normre: 2.29e-09, normupdt: 1.30e-02, α: -0.072, eltime: 2.87 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.31e-05, normre: 6.03e-11, eltime: 2.33 sec.
# step 97 done in  3 iter, after 8.21 sec.
#
# doing step  98/301, LF = 0.6859, w0 = 171.465
# iter:  0, norm0: 0.00e+00, normru: 7.02e-05, normre: 8.84e-01, normupdt: 9.20e-01, α:    NaN, eltime: 3.01 sec.
# iter:  1, norm0: 0.00e+00, normru: 2.25e-02, normre: 2.58e-09, normupdt: 2.27e-02, α: -0.130, eltime: 3.12 sec.
# iter:  2, norm0: 0.00e+00, normru: 3.98e-05, normre: 3.52e-11, eltime: 2.24 sec.
# step 98 done in  3 iter, after 8.38 sec.
#
# doing step  99/301, LF = 0.6929, w0 = 173.232
# iter:  0, norm0: 0.00e+00, normru: 7.96e-05, normre: 8.84e-01, normupdt: 9.43e-01, α:    NaN, eltime: 2.46 sec.
# iter:  1, norm0: 0.00e+00, normru: 2.71e-02, normre: 2.80e-09, normupdt: 2.72e-02, α: -0.152, eltime: 2.56 sec.
# iter:  2, norm0: 0.00e+00, normru: 5.68e-05, normre: 5.75e-11, eltime: 1.97 sec.
# step 99 done in  3 iter, after 6.99 sec.
#
# doing step 100/301, LF = 0.7000, w0 = 175.000
# iter:  0, norm0: 0.00e+00, normru: 8.94e-05, normre: 8.84e-01, normupdt: 9.75e-01, α:    NaN, eltime: 2.39 sec.
# iter:  1, norm0: 0.00e+00, normru: 2.98e-02, normre: 2.83e-09, normupdt: 2.98e-02, α: -0.162, eltime: 2.60 sec.
# iter:  2, norm0: 0.00e+00, normru: 6.87e-05, normre: 9.75e-12, eltime: 2.16 sec.
# step 100 done in  3 iter, after 7.15 sec.
#
# doing step 101/301, LF = 0.7000, w0 = 175.000
# iter:  0, norm0: 0.00e+00, normru: 6.87e-05, normre: 9.75e-12, eltime: 2.12 sec.
# step 101 done in  1 iter, after 2.12 sec.
#
# doing step 102/301, LF = 0.7015, w0 = 175.375
# iter:  0, norm0: 0.00e+00, normru: 7.02e-05, normre: 1.88e-01, normupdt: 2.59e-01, α:    NaN, eltime: 3.01 sec.
# iter:  1, norm0: 0.00e+00, normru: 2.21e-03, normre: 2.88e-10, normupdt: 6.27e-03, α: -0.093, eltime: 3.25 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.88e-06, normre: 2.87e-12, eltime: 1.89 sec.
# step 102 done in  3 iter, after 8.15 sec.
#
# doing step 103/301, LF = 0.7030, w0 = 175.750
# iter:  0, norm0: 0.00e+00, normru: 1.47e-05, normre: 1.88e-01, normupdt: 1.98e-01, α:    NaN, eltime: 2.17 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.23e-03, normre: 3.72e-10, normupdt: 1.16e-03, α: -0.045, eltime: 2.88 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.29e-07, normre: 3.18e-12, eltime: 1.53 sec.
# step 103 done in  3 iter, after 6.57 sec.
#
# doing step 104/301, LF = 0.7045, w0 = 176.125
# iter:  0, norm0: 0.00e+00, normru: 1.46e-05, normre: 1.87e-01, normupdt: 1.97e-01, α:    NaN, eltime: 2.11 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.23e-03, normre: 6.94e-10, normupdt: 1.18e-03, α: -0.056, eltime: 2.29 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.26e-07, normre: 2.42e-12, eltime: 1.93 sec.
# step 104 done in  3 iter, after 6.33 sec.
#
# doing step 105/301, LF = 0.7060, w0 = 176.500
# iter:  0, norm0: 0.00e+00, normru: 1.46e-05, normre: 1.87e-01, normupdt: 2.20e-01, α:    NaN, eltime: 3.03 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.53e-03, normre: 1.54e-10, normupdt: 1.45e-03, α: -0.085, eltime: 3.32 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.92e-07, normre: 6.82e-13, eltime: 1.77 sec.
# step 105 done in  3 iter, after 8.12 sec.
#
# doing step 106/301, LF = 0.7075, w0 = 176.875
# iter:  0, norm0: 0.00e+00, normru: 1.46e-05, normre: 1.88e-01, normupdt: 2.23e-01, α:    NaN, eltime: 2.31 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.57e-03, normre: 3.24e-10, normupdt: 1.49e-03, α: -0.084, eltime: 2.72 sec.
# iter:  2, norm0: 0.00e+00, normru: 2.03e-07, normre: 1.95e-12, eltime: 2.02 sec.
# step 106 done in  3 iter, after 7.06 sec.
#
# doing step 107/301, LF = 0.7090, w0 = 177.250
# iter:  0, norm0: 0.00e+00, normru: 1.46e-05, normre: 1.87e-01, normupdt: 2.26e-01, α:    NaN, eltime: 2.38 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.61e-03, normre: 9.30e-10, normupdt: 1.53e-03, α: -0.085, eltime: 3.49 sec.
# iter:  2, norm0: 0.00e+00, normru: 2.13e-07, normre: 1.38e-12, eltime: 2.05 sec.
# step 107 done in  3 iter, after 7.92 sec.
#
# doing step 108/301, LF = 0.7105, w0 = 177.625
# iter:  0, norm0: 0.00e+00, normru: 1.46e-05, normre: 1.88e-01, normupdt: 2.28e-01, α:    NaN, eltime: 2.77 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.66e-03, normre: 4.39e-10, normupdt: 1.57e-03, α: -0.084, eltime: 2.43 sec.
# iter:  2, norm0: 0.00e+00, normru: 2.26e-07, normre: 4.62e-12, eltime: 1.97 sec.
# step 108 done in  3 iter, after 7.20 sec.
#
# doing step 109/301, LF = 0.7120, w0 = 178.000
# iter:  0, norm0: 0.00e+00, normru: 1.46e-05, normre: 1.88e-01, normupdt: 2.31e-01, α:    NaN, eltime: 2.08 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.70e-03, normre: 8.70e-10, normupdt: 1.61e-03, α: -0.085, eltime: 2.73 sec.
# iter:  2, norm0: 0.00e+00, normru: 2.38e-07, normre: 7.53e-12, eltime: 1.62 sec.
# step 109 done in  3 iter, after 6.44 sec.
#
# doing step 110/301, LF = 0.7135, w0 = 178.375
# iter:  0, norm0: 0.00e+00, normru: 1.46e-05, normre: 1.88e-01, normupdt: 2.34e-01, α:    NaN, eltime: 1.95 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.76e-03, normre: 5.45e-10, normupdt: 1.65e-03, α: -0.084, eltime: 2.07 sec.
# iter:  2, norm0: 0.00e+00, normru: 2.52e-07, normre: 2.69e-12, eltime: 1.59 sec.
# step 110 done in  3 iter, after 5.61 sec.
#
# doing step 111/301, LF = 0.7150, w0 = 178.750
# iter:  0, norm0: 0.00e+00, normru: 1.46e-05, normre: 1.88e-01, normupdt: 2.37e-01, α:    NaN, eltime: 1.83 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.80e-03, normre: 4.82e-10, normupdt: 1.70e-03, α: -0.085, eltime: 2.12 sec.
# iter:  2, norm0: 0.00e+00, normru: 2.66e-07, normre: 8.67e-13, eltime: 1.50 sec.
# step 111 done in  3 iter, after 5.45 sec.
#
# doing step 112/301, LF = 0.7165, w0 = 179.125
# iter:  0, norm0: 0.00e+00, normru: 1.46e-05, normre: 1.88e-01, normupdt: 2.40e-01, α:    NaN, eltime: 2.20 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.86e-03, normre: 8.05e-10, normupdt: 1.74e-03, α: -0.084, eltime: 1.89 sec.
# iter:  2, norm0: 0.00e+00, normru: 2.81e-07, normre: 4.96e-12, eltime: 1.61 sec.
# step 112 done in  3 iter, after 5.70 sec.
#
# doing step 113/301, LF = 0.7180, w0 = 179.500
# iter:  0, norm0: 0.00e+00, normru: 1.46e-05, normre: 1.87e-01, normupdt: 2.43e-01, α:    NaN, eltime: 1.85 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.90e-03, normre: 3.53e-10, normupdt: 1.79e-03, α: -0.085, eltime: 2.21 sec.
# iter:  2, norm0: 0.00e+00, normru: 2.96e-07, normre: 1.18e-12, eltime: 1.44 sec.
# step 113 done in  3 iter, after 5.50 sec.
#
# doing step 114/301, LF = 0.7195, w0 = 179.875
# iter:  0, norm0: 0.00e+00, normru: 1.46e-05, normre: 1.88e-01, normupdt: 2.46e-01, α:    NaN, eltime: 1.95 sec.
# iter:  1, norm0: 0.00e+00, normru: 1.96e-03, normre: 3.10e-10, normupdt: 1.83e-03, α: -0.084, eltime: 2.11 sec.
# iter:  2, norm0: 0.00e+00, normru: 3.14e-07, normre: 2.22e-12, eltime: 1.60 sec.
# step 114 done in  3 iter, after 5.66 sec.
#
# doing step 115/301, LF = 0.7210, w0 = 180.250
# iter:  0, norm0: 0.00e+00, normru: 1.46e-05, normre: 1.88e-01, normupdt: 2.49e-01, α:    NaN, eltime: 1.92 sec.
# iter:  1, norm0: 0.00e+00, normru: 2.01e-03, normre: 2.61e-10, normupdt: 1.88e-03, α: -0.085, eltime: 2.02 sec.
# iter:  2, norm0: 0.00e+00, normru: 3.31e-07, normre: 3.30e-12, eltime: 1.46 sec.
# step 115 done in  3 iter, after 5.39 sec.
#
# doing step 116/301, LF = 0.7225, w0 = 180.625
# iter:  0, norm0: 0.00e+00, normru: 1.46e-05, normre: 1.88e-01, normupdt: 2.52e-01, α:    NaN, eltime: 1.91 sec.
# iter:  1, norm0: 0.00e+00, normru: 2.08e-03, normre: 7.28e-10, normupdt: 1.93e-03, α: -0.084, eltime: 2.11 sec.
# iter:  2, norm0: 0.00e+00, normru: 3.50e-07, normre: 2.93e-12, eltime: 1.59 sec.
# step 116 done in  3 iter, after 5.61 sec.
#
# doing step 117/301, LF = 0.7240, w0 = 181.000
# iter:  0, norm0: 0.00e+00, normru: 1.46e-05, normre: 1.87e-01, normupdt: 2.56e-01, α:    NaN, eltime: 1.93 sec.
# iter:  1, norm0: 0.00e+00, normru: 2.13e-03, normre: 3.04e-10, normupdt: 1.98e-03, α: -0.084, eltime: 2.64 sec.
# iter:  2, norm0: 0.00e+00, normru: 3.69e-07, normre: 9.52e-13, eltime: 1.54 sec.
# step 117 done in  3 iter, after 6.11 sec.
#
# doing step 118/301, LF = 0.7255, w0 = 181.375
# iter:  0, norm0: 0.00e+00, normru: 1.46e-05, normre: 1.88e-01, normupdt: 2.59e-01, α:    NaN, eltime: 1.81 sec.
# iter:  1, norm0: 0.00e+00, normru: 2.20e-03, normre: 9.97e-10, normupdt: 2.03e-03, α: -0.083, eltime: 2.01 sec.
# iter:  2, norm0: 0.00e+00, normru: 3.90e-07, normre: 3.28e-12, eltime: 1.58 sec.
# step 118 done in  3 iter, after 5.41 sec.
#
# doing step 119/301, LF = 0.7270, w0 = 181.750
# iter:  0, norm0: 0.00e+00, normru: 1.46e-05, normre: 1.88e-01, normupdt: 2.62e-01, α:    NaN, eltime: 1.83 sec.
# iter:  1, norm0: 0.00e+00, normru: 2.25e-03, normre: 4.56e-10, normupdt: 2.09e-03, α: -0.084, eltime: 2.02 sec.
# iter:  2, norm0: 0.00e+00, normru: 4.12e-07, normre: 2.34e-12, eltime: 1.85 sec.
# step 119 done in  3 iter, after 5.70 sec.
#
# doing step 120/301, LF = 0.7285, w0 = 182.125
# iter:  0, norm0: 0.00e+00, normru: 1.46e-05, normre: 1.88e-01, normupdt: 2.65e-01, α:    NaN, eltime: 2.20 sec.
# iter:  1, norm0: 0.00e+00, normru: 2.32e-03, normre: 4.36e-10, normupdt: 2.14e-03, α: -0.083, eltime: 2.25 sec.
# iter:  2, norm0: 0.00e+00, normru: 4.35e-07, normre: 4.63e-12, eltime: 1.44 sec.
# step 120 done in  3 iter, after 5.88 sec.
#
# doing step 121/301, LF = 0.7300, w0 = 182.500
# iter:  0, norm0: 0.00e+00, normru: 1.46e-05, normre: 1.87e-01, normupdt: 2.69e-01, α:    NaN, eltime: 1.83 sec.
# iter:  1, norm0: 0.00e+00, normru: 2.38e-03, normre: 8.36e-10, normupdt: 2.20e-03, α: -0.083, eltime: 2.00 sec.
# iter:  2, norm0: 0.00e+00, normru: 4.59e-07, normre: 3.25e-12, eltime: 1.58 sec.
# step 121 done in  3 iter, after 5.40 sec.
#
# doing step 122/301, LF = 0.7315, w0 = 182.875
# iter:  0, norm0: 0.00e+00, normru: 1.46e-05, normre: 1.88e-01, normupdt: 2.72e-01, α:    NaN, eltime: 1.80 sec.
# iter:  1, norm0: 0.00e+00, normru: 2.45e-03, normre: 1.60e-09, normupdt: 2.25e-03, α: -0.082, eltime: 2.17 sec.
# iter:  2, norm0: 0.00e+00, normru: 4.86e-07, normre: 9.58e-12, eltime: 1.39 sec.
# step 122 done in  3 iter, after 5.36 sec.
#
# doing step 123/301, LF = 0.7330, w0 = 183.250
# iter:  0, norm0: 0.00e+00, normru: 1.46e-05, normre: 1.88e-01, normupdt: 2.75e-01, α:    NaN, eltime: 1.87 sec.
# iter:  1, norm0: 0.00e+00, normru: 2.51e-03, normre: 3.77e-10, normupdt: 2.32e-03, α: -0.082, eltime: 1.88 sec.
# iter:  2, norm0: 0.00e+00, normru: 5.12e-07, normre: 9.09e-13, eltime: 1.61 sec.
# step 123 done in  3 iter, after 5.36 sec.
#
# doing step 124/301, LF = 0.7345, w0 = 183.625
# iter:  0, norm0: 0.00e+00, normru: 1.46e-05, normre: 1.88e-01, normupdt: 2.79e-01, α:    NaN, eltime: 1.87 sec.
# iter:  1, norm0: 0.00e+00, normru: 2.59e-03, normre: 1.12e-09, normupdt: 2.37e-03, α: -0.081, eltime: 2.09 sec.
# iter:  2, norm0: 0.00e+00, normru: 5.42e-07, normre: 5.17e-12, eltime: 1.44 sec.
# step 124 done in  3 iter, after 5.40 sec.
#
# doing step 125/301, LF = 0.7360, w0 = 184.000
# iter:  0, norm0: 0.00e+00, normru: 1.46e-05, normre: 1.87e-01, normupdt: 2.82e-01, α:    NaN, eltime: 2.12 sec.
# iter:  1, norm0: 0.00e+00, normru: 2.66e-03, normre: 8.17e-10, normupdt: 2.44e-03, α: -0.081, eltime: 2.26 sec.
# iter:  2, norm0: 0.00e+00, normru: 5.71e-07, normre: 1.71e-12, eltime: 1.59 sec.
# step 125 done in  3 iter, after 5.97 sec.
#
# doing step 126/301, LF = 0.7375, w0 = 184.375
# iter:  0, norm0: 0.00e+00, normru: 1.46e-05, normre: 1.88e-01, normupdt: 2.85e-01, α:    NaN, eltime: 1.84 sec.
# iter:  1, norm0: 0.00e+00, normru: 2.74e-03, normre: 6.42e-10, normupdt: 2.50e-03, α: -0.080, eltime: 2.19 sec.
# iter:  2, norm0: 0.00e+00, normru: 6.04e-07, normre: 9.02e-12, eltime: 1.41 sec.
# step 126 done in  3 iter, after 5.45 sec.
#
# doing step 127/301, LF = 0.7390, w0 = 184.750
# iter:  0, norm0: 0.00e+00, normru: 1.46e-05, normre: 1.88e-01, normupdt: 2.89e-01, α:    NaN, eltime: 2.00 sec.
# iter:  1, norm0: 0.00e+00, normru: 2.81e-03, normre: 4.35e-10, normupdt: 2.57e-03, α: -0.080, eltime: 2.72 sec.
# iter:  2, norm0: 0.00e+00, normru: 6.37e-07, normre: 6.82e-12, eltime: 1.68 sec.
# step 127 done in  3 iter, after 6.41 sec.
#
# doing step 128/301, LF = 0.7405, w0 = 185.125
# iter:  0, norm0: 0.00e+00, normru: 1.46e-05, normre: 1.88e-01, normupdt: 2.93e-01, α:    NaN, eltime: 1.82 sec.
# iter:  1, norm0: 0.00e+00, normru: 2.90e-03, normre: 5.76e-10, normupdt: 2.63e-03, α: -0.079, eltime: 2.18 sec.
# iter:  2, norm0: 0.00e+00, normru: 6.74e-07, normre: 5.00e-12, eltime: 1.42 sec.
# step 128 done in  3 iter, after 5.42 sec.
#
# doing step 129/301, LF = 0.7420, w0 = 185.500
# iter:  0, norm0: 0.00e+00, normru: 1.46e-05, normre: 1.88e-01, normupdt: 2.96e-01, α:    NaN, eltime: 1.99 sec.
# iter:  1, norm0: 0.00e+00, normru: 2.97e-03, normre: 2.94e-10, normupdt: 2.70e-03, α: -0.079, eltime: 1.93 sec.
# iter:  2, norm0: 0.00e+00, normru: 7.11e-07, normre: 4.77e-12, eltime: 1.63 sec.
# step 129 done in  3 iter, after 5.55 sec.
#
# doing step 130/301, LF = 0.7435, w0 = 185.875
# iter:  0, norm0: 0.00e+00, normru: 1.46e-05, normre: 1.88e-01, normupdt: 3.00e-01, α:    NaN, eltime: 1.88 sec.
# iter:  1, norm0: 0.00e+00, normru: 3.06e-03, normre: 5.68e-10, normupdt: 2.77e-03, α: -0.078, eltime: 2.04 sec.
# iter:  2, norm0: 0.00e+00, normru: 7.52e-07, normre: 7.25e-12, eltime: 1.60 sec.
# step 130 done in  3 iter, after 5.52 sec.
#
# doing step 131/301, LF = 0.7450, w0 = 186.250
# iter:  0, norm0: 0.00e+00, normru: 1.46e-05, normre: 1.88e-01, normupdt: 3.04e-01, α:    NaN, eltime: 1.82 sec.
# iter:  1, norm0: 0.00e+00, normru: 3.14e-03, normre: 8.43e-10, normupdt: 2.85e-03, α: -0.078, eltime: 2.29 sec.
# iter:  2, norm0: 0.00e+00, normru: 7.93e-07, normre: 7.02e-12, eltime: 1.76 sec.
# step 131 done in  3 iter, after 5.88 sec.
#
# doing step 132/301, LF = 0.7465, w0 = 186.625
# iter:  0, norm0: 0.00e+00, normru: 1.47e-05, normre: 1.87e-01, normupdt: 3.07e-01, α:    NaN, eltime: 2.27 sec.
# iter:  1, norm0: 0.00e+00, normru: 3.24e-03, normre: 3.14e-10, normupdt: 2.91e-03, α: -0.077, eltime: 2.38 sec.
# iter:  2, norm0: 0.00e+00, normru: 8.39e-07, normre: 1.90e-12, eltime: 1.75 sec.
# step 132 done in  3 iter, after 6.41 sec.
#
# doing step 133/301, LF = 0.7480, w0 = 187.000
# iter:  0, norm0: 0.00e+00, normru: 1.47e-05, normre: 1.88e-01, normupdt: 3.11e-01, α:    NaN, eltime: 1.81 sec.
# iter:  1, norm0: 0.00e+00, normru: 3.32e-03, normre: 7.92e-10, normupdt: 3.00e-03, α: -0.077, eltime: 2.18 sec.
# iter:  2, norm0: 0.00e+00, normru: 8.85e-07, normre: 4.41e-12, eltime: 1.37 sec.
# step 133 done in  3 iter, after 5.36 sec.
#
# doing step 134/301, LF = 0.7495, w0 = 187.375
# iter:  0, norm0: 0.00e+00, normru: 1.47e-05, normre: 1.87e-01, normupdt: 3.15e-01, α:    NaN, eltime: 1.93 sec.
# iter:  1, norm0: 0.00e+00, normru: 3.43e-03, normre: 2.97e-10, normupdt: 3.06e-03, α: -0.075, eltime: 1.90 sec.
# iter:  2, norm0: 0.00e+00, normru: 9.37e-07, normre: 3.79e-12, eltime: 1.61 sec.
# step 134 done in  3 iter, after 5.44 sec.
#
# doing step 135/301, LF = 0.7510, w0 = 187.750
# iter:  0, norm0: 0.00e+00, normru: 1.47e-05, normre: 1.87e-01, normupdt: 3.19e-01, α:    NaN, eltime: 1.84 sec.
# iter:  1, norm0: 0.00e+00, normru: 3.51e-03, normre: 2.88e-10, normupdt: 3.15e-03, α: -0.076, eltime: 2.44 sec.
# iter:  2, norm0: 0.00e+00, normru: 9.88e-07, normre: 4.87e-12, eltime: 1.99 sec.
# step 135 done in  3 iter, after 6.27 sec.
#
# doing step 136/301, LF = 0.7525, w0 = 188.125
# iter:  0, norm0: 0.00e+00, normru: 1.47e-05, normre: 1.88e-01, normupdt: 3.23e-01, α:    NaN, eltime: 2.29 sec.
# iter:  1, norm0: 0.00e+00, normru: 3.62e-03, normre: 4.99e-10, normupdt: 3.23e-03, α: -0.074, eltime: 2.22 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.05e-06, normre: 1.05e-12, eltime: 1.38 sec.
# step 136 done in  3 iter, after 5.89 sec.
#
# doing step 137/301, LF = 0.7540, w0 = 188.500
# iter:  0, norm0: 0.00e+00, normru: 1.47e-05, normre: 1.88e-01, normupdt: 3.27e-01, α:    NaN, eltime: 1.91 sec.
# iter:  1, norm0: 0.00e+00, normru: 3.72e-03, normre: 3.19e-10, normupdt: 3.32e-03, α: -0.074, eltime: 2.05 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.10e-06, normre: 4.12e-12, eltime: 1.60 sec.
# step 137 done in  3 iter, after 5.56 sec.
#
# doing step 138/301, LF = 0.7555, w0 = 188.875
# iter:  0, norm0: 0.00e+00, normru: 1.47e-05, normre: 1.88e-01, normupdt: 3.31e-01, α:    NaN, eltime: 1.89 sec.
# iter:  1, norm0: 0.00e+00, normru: 3.83e-03, normre: 1.20e-09, normupdt: 3.40e-03, α: -0.073, eltime: 2.20 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.17e-06, normre: 6.76e-12, eltime: 1.41 sec.
# step 138 done in  3 iter, after 5.50 sec.
#
# doing step 139/301, LF = 0.7570, w0 = 189.250
# iter:  0, norm0: 0.00e+00, normru: 1.47e-05, normre: 1.88e-01, normupdt: 3.35e-01, α:    NaN, eltime: 1.95 sec.
# iter:  1, norm0: 0.00e+00, normru: 3.93e-03, normre: 5.21e-10, normupdt: 3.50e-03, α: -0.073, eltime: 1.97 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.23e-06, normre: 3.18e-12, eltime: 1.64 sec.
# step 139 done in  3 iter, after 5.56 sec.
#
# doing step 140/301, LF = 0.7585, w0 = 189.625
# iter:  0, norm0: 0.00e+00, normru: 1.47e-05, normre: 1.88e-01, normupdt: 3.39e-01, α:    NaN, eltime: 1.79 sec.
# iter:  1, norm0: 0.00e+00, normru: 4.06e-03, normre: 1.09e-09, normupdt: 3.58e-03, α: -0.071, eltime: 2.42 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.31e-06, normre: 9.17e-12, eltime: 1.75 sec.
# step 140 done in  3 iter, after 5.96 sec.
#
# doing step 141/301, LF = 0.7600, w0 = 190.000
# iter:  0, norm0: 0.00e+00, normru: 1.47e-05, normre: 1.88e-01, normupdt: 3.43e-01, α:    NaN, eltime: 2.65 sec.
# iter:  1, norm0: 0.00e+00, normru: 4.16e-03, normre: 8.09e-10, normupdt: 3.68e-03, α: -0.072, eltime: 2.16 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.38e-06, normre: 8.48e-12, eltime: 1.61 sec.
# step 141 done in  3 iter, after 6.41 sec.
#
# doing step 142/301, LF = 0.7615, w0 = 190.375
# iter:  0, norm0: 0.00e+00, normru: 1.47e-05, normre: 1.88e-01, normupdt: 3.47e-01, α:    NaN, eltime: 1.81 sec.
# iter:  1, norm0: 0.00e+00, normru: 4.29e-03, normre: 6.92e-10, normupdt: 3.78e-03, α: -0.070, eltime: 2.14 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.46e-06, normre: 5.91e-12, eltime: 1.46 sec.
# step 142 done in  3 iter, after 5.40 sec.
#
# doing step 143/301, LF = 0.7630, w0 = 190.750
# iter:  0, norm0: 0.00e+00, normru: 1.47e-05, normre: 1.88e-01, normupdt: 3.52e-01, α:    NaN, eltime: 1.92 sec.
# iter:  1, norm0: 0.00e+00, normru: 4.40e-03, normre: 9.44e-10, normupdt: 3.88e-03, α: -0.070, eltime: 2.08 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.54e-06, normre: 3.34e-12, eltime: 1.63 sec.
# step 143 done in  3 iter, after 5.63 sec.
#
# doing step 144/301, LF = 0.7645, w0 = 191.125
# iter:  0, norm0: 0.00e+00, normru: 1.47e-05, normre: 1.88e-01, normupdt: 3.56e-01, α:    NaN, eltime: 1.86 sec.
# iter:  1, norm0: 0.00e+00, normru: 4.54e-03, normre: 6.37e-10, normupdt: 3.99e-03, α: -0.068, eltime: 2.12 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.63e-06, normre: 6.92e-12, eltime: 1.88 sec.
# step 144 done in  3 iter, after 5.87 sec.
#
# doing step 145/301, LF = 0.7660, w0 = 191.500
# iter:  0, norm0: 0.00e+00, normru: 1.47e-05, normre: 1.88e-01, normupdt: 3.61e-01, α:    NaN, eltime: 1.90 sec.
# iter:  1, norm0: 0.00e+00, normru: 4.66e-03, normre: 6.26e-10, normupdt: 4.10e-03, α: -0.069, eltime: 2.12 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.72e-06, normre: 8.11e-12, eltime: 1.63 sec.
# step 145 done in  3 iter, after 5.66 sec.
#
# doing step 146/301, LF = 0.7675, w0 = 191.875
# iter:  0, norm0: 0.00e+00, normru: 1.47e-05, normre: 1.87e-01, normupdt: 3.65e-01, α:    NaN, eltime: 1.90 sec.
# iter:  1, norm0: 0.00e+00, normru: 4.81e-03, normre: 1.17e-09, normupdt: 4.21e-03, α: -0.067, eltime: 2.05 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.82e-06, normre: 1.33e-11, eltime: 1.63 sec.
# step 146 done in  3 iter, after 5.58 sec.
#
# doing step 147/301, LF = 0.7690, w0 = 192.250
# iter:  0, norm0: 0.00e+00, normru: 1.47e-05, normre: 1.88e-01, normupdt: 3.70e-01, α:    NaN, eltime: 2.25 sec.
# iter:  1, norm0: 0.00e+00, normru: 4.94e-03, normre: 6.07e-10, normupdt: 4.32e-03, α: -0.067, eltime: 2.04 sec.
# iter:  2, norm0: 0.00e+00, normru: 1.92e-06, normre: 5.91e-12, eltime: 1.43 sec.
# step 147 done in  3 iter, after 5.72 sec.
#
# doing step 148/301, LF = 0.7705, w0 = 192.625
# iter:  0, norm0: 0.00e+00, normru: 1.48e-05, normre: 1.88e-01, normupdt: 3.74e-01, α:    NaN, eltime: 1.98 sec.
# iter:  1, norm0: 0.00e+00, normru: 5.09e-03, normre: 7.24e-10, normupdt: 4.44e-03, α: -0.065, eltime: 2.08 sec.
# iter:  2, norm0: 0.00e+00, normru: 2.04e-06, normre: 3.60e-12, eltime: 1.62 sec.
# step 148 done in  3 iter, after 5.68 sec.
#
# doing step 149/301, LF = 0.7720, w0 = 193.000
# iter:  0, norm0: 0.00e+00, normru: 1.48e-05, normre: 1.87e-01, normupdt: 3.79e-01, α:    NaN, eltime: 1.80 sec.
# iter:  1, norm0: 0.00e+00, normru: 5.23e-03, normre: 6.40e-10, normupdt: 4.56e-03, α: -0.066, eltime: 2.42 sec.
# iter:  2, norm0: 0.00e+00, normru: 2.15e-06, normre: 2.96e-12, eltime: 1.69 sec.
# step 149 done in  3 iter, after 5.91 sec.
#
# doing step 150/301, LF = 0.7735, w0 = 193.375
# iter:  0, norm0: 0.00e+00, normru: 1.48e-05, normre: 1.88e-01, normupdt: 3.83e-01, α:    NaN, eltime: 1.81 sec.
# iter:  1, norm0: 0.00e+00, normru: 5.39e-03, normre: 2.24e-10, normupdt: 4.68e-03, α: -0.064, eltime: 2.09 sec.
# iter:  2, norm0: 0.00e+00, normru: 2.28e-06, normre: 1.48e-12, eltime: 1.45 sec.
# step 150 done in  3 iter, after 5.34 sec.
#
# doing step 151/301, LF = 0.7750, w0 = 193.750
# iter:  0, norm0: 0.00e+00, normru: 1.48e-05, normre: 1.88e-01, normupdt: 3.88e-01, α:    NaN, eltime: 1.93 sec.
# iter:  1, norm0: 0.00e+00, normru: 5.54e-03, normre: 1.12e-09, normupdt: 4.81e-03, α: -0.064, eltime: 2.02 sec.
# iter:  2, norm0: 0.00e+00, normru: 2.41e-06, normre: 1.52e-11, eltime: 1.61 sec.
# step 151 done in  3 iter, after 5.57 sec.
#
# doing step 152/301, LF = 0.7765, w0 = 194.125
# iter:  0, norm0: 0.00e+00, normru: 1.48e-05, normre: 1.88e-01, normupdt: 3.92e-01, α:    NaN, eltime: 1.84 sec.
# iter:  1, norm0: 0.00e+00, normru: 5.71e-03, normre: 9.40e-10, normupdt: 4.94e-03, α: -0.062, eltime: 2.14 sec.
# iter:  2, norm0: 0.00e+00, normru: 2.56e-06, normre: 3.27e-12, eltime: 1.46 sec.
# step 152 done in  3 iter, after 5.44 sec.
#
# doing step 153/301, LF = 0.7780, w0 = 194.500
# iter:  0, norm0: 0.00e+00, normru: 1.49e-05, normre: 1.87e-01, normupdt: 3.98e-01, α:    NaN, eltime: 1.92 sec.
# iter:  1, norm0: 0.00e+00, normru: 5.87e-03, normre: 7.54e-10, normupdt: 5.08e-03, α: -0.062, eltime: 2.50 sec.
# iter:  2, norm0: 0.00e+00, normru: 2.70e-06, normre: 5.00e-12, eltime: 1.90 sec.
# step 153 done in  3 iter, after 6.33 sec.
#
# doing step 154/301, LF = 0.7795, w0 = 194.875
# iter:  0, norm0: 0.00e+00, normru: 1.49e-05, normre: 1.87e-01, normupdt: 4.02e-01, α:    NaN, eltime: 1.83 sec.
# iter:  1, norm0: 0.00e+00, normru: 6.05e-03, normre: 3.32e-10, normupdt: 5.21e-03, α: -0.061, eltime: 1.94 sec.
# iter:  2, norm0: 0.00e+00, normru: 2.86e-06, normre: 2.61e-12, eltime: 1.61 sec.
# step 154 done in  3 iter, after 5.38 sec.
#
# doing step 155/301, LF = 0.7810, w0 = 195.250
# iter:  0, norm0: 0.00e+00, normru: 1.49e-05, normre: 1.87e-01, normupdt: 4.08e-01, α:    NaN, eltime: 1.81 sec.
# iter:  1, norm0: 0.00e+00, normru: 6.22e-03, normre: 1.79e-09, normupdt: 5.36e-03, α: -0.061, eltime: 2.09 sec.
# iter:  2, norm0: 0.00e+00, normru: 3.03e-06, normre: 8.71e-12, eltime: 1.77 sec.
# step 155 done in  3 iter, after 5.66 sec.
#
# doing step 156/301, LF = 0.7825, w0 = 195.625
# iter:  0, norm0: 0.00e+00, normru: 1.49e-05, normre: 1.88e-01, normupdt: 4.12e-01, α:    NaN, eltime: 2.28 sec.
# iter:  1, norm0: 0.00e+00, normru: 6.42e-03, normre: 7.54e-10, normupdt: 5.50e-03, α: -0.059, eltime: 2.08 sec.
# iter:  2, norm0: 0.00e+00, normru: 3.21e-06, normre: 1.82e-12, eltime: 1.61 sec.
# step 156 done in  3 iter, after 5.98 sec.
#
# doing step 157/301, LF = 0.7840, w0 = 196.000
# iter:  0, norm0: 0.00e+00, normru: 1.50e-05, normre: 1.87e-01, normupdt: 4.18e-01, α:    NaN, eltime: 1.83 sec.
# iter:  1, norm0: 0.00e+00, normru: 6.59e-03, normre: 7.33e-10, normupdt: 5.66e-03, α: -0.059, eltime: 2.28 sec.
# iter:  2, norm0: 0.00e+00, normru: 3.39e-06, normre: 5.07e-12, eltime: 1.44 sec.
# step 157 done in  3 iter, after 5.55 sec.
#
# doing step 158/301, LF = 0.7855, w0 = 196.375
# iter:  0, norm0: 0.00e+00, normru: 1.50e-05, normre: 1.88e-01, normupdt: 4.22e-01, α:    NaN, eltime: 1.95 sec.
# iter:  1, norm0: 0.00e+00, normru: 6.80e-03, normre: 6.62e-10, normupdt: 5.80e-03, α: -0.058, eltime: 1.90 sec.
# iter:  2, norm0: 0.00e+00, normru: 3.60e-06, normre: 3.10e-12, eltime: 1.61 sec.
# step 158 done in  3 iter, after 5.45 sec.
#
# doing step 159/301, LF = 0.7870, w0 = 196.750
# iter:  0, norm0: 0.00e+00, normru: 1.51e-05, normre: 1.87e-01, normupdt: 4.28e-01, α:    NaN, eltime: 1.84 sec.
# iter:  1, norm0: 0.00e+00, normru: 6.99e-03, normre: 3.67e-10, normupdt: 5.97e-03, α: -0.058, eltime: 2.57 sec.
# iter:  2, norm0: 0.00e+00, normru: 3.80e-06, normre: 4.29e-12, eltime: 1.56 sec.
# step 159 done in  3 iter, after 5.98 sec.
#
# doing step 160/301, LF = 0.7885, w0 = 197.125
# iter:  0, norm0: 0.00e+00, normru: 1.51e-05, normre: 1.88e-01, normupdt: 4.32e-01, α:    NaN, eltime: 1.97 sec.

# %%
# these lines will produce vtu and pvd files for paraview
#=
using WriteVTK

cells     = [MeshCell(VTKCellTypes.VTK_HEXAHEDRON, item) for item in el_nodes]
points    = hcat(nodes...)

paraview_collection(sVTKpath*sFileName) do pvd
  for (ii, item) in enumerate(allus)
    (u0,rf) = item[1:2]
    F   = Elements.getinfo(elems,u0,info=:F)
    LE  = Elements.getinfo(elems,u0,info=:LE)
    J   = [det(F) for F in F]
    E   = [0.5*(transpose(F)*F-I) for F in F]
    σ   = [Materials.getinfo(F,mat,info=:σ)        for F in F]  # Cauchy stress
    S   = [Materials.getinfo(F,mat,info=:S)        for F in F]  # 2nd PK
    Ii  = [Materials.getInvariants(transpose(F)F)  for F in F]  # 2nd PK
    σP  = [sort(eigvals(σ))  for σ  in σ]
    σVM = [sqrt((x[1]-x[2])^2+(x[2]-x[3])^2+(x[3]-x[1])^2)/sqrt(2)  for x in σP]

    vtkobj  = vtk_grid(@sprintf("%s_%03i", sVTKpath*sFileName, ii), points+u0, cells)
    vtk_point_data(vtkobj, (u0[1,:],u0[2,:],u0[3,:]),                   "u")
    vtk_point_data(vtkobj, (rf[1,:],rf[2,:],rf[3,:]),                   "rf")
    vtk_cell_data(vtkobj,  tuple([getindex.(F,ii)  for ii in 1:9]...),  "F")
    vtk_cell_data(vtkobj,  tuple([getindex.(LE,ii)  for ii in 1:9]...), "LE")
    vtk_cell_data(vtkobj,  J,   "J")
    vtk_cell_data(vtkobj,  tuple([getindex.(σ,ii)   for ii in 1:9]...), "\$\\sigma\$")
    vtk_cell_data(vtkobj,  tuple([getindex.(σP,ii)  for ii in 1:3]...), "\$\\sigma_p\$")
    vtk_cell_data(vtkobj,  tuple([getindex.(Ii,ii)  for ii in 1:3]...), "I")
    vtk_cell_data(vtkobj,  σVM, "\$\\sigma_{VM}\$")

    collection_add_timestep(pvd, vtkobj, ii)
    vtk_save(vtkobj)
  end
end  

=#
